# %%
# imports
import tensorflow as tf
import pretty_midi as pm
import matplotlib.pyplot as plt
import mido as m
import numpy as np
from basic_pitch.inference import predict
from basic_pitch import ICASSP_2022_MODEL_PATH
basic_pitch_model = tf.saved_model.load(str(ICASSP_2022_MODEL_PATH))

# %%
pm_data = pm.PrettyMIDI("C:\\Users\\Tim\\Documents\\GitHub\\purdue-AIMA-basic-pitch-testing\\Tim\'s songs\\Blind Composition Render\\blind comp render E-PIANO ONLY_basic_pitch.mid")
midi = m.MidiFile("C:\\Users\\Tim\\Documents\\GitHub\\purdue-AIMA-basic-pitch-testing\\Tim\'s songs\\Blind Composition Render\\blind comp render E-PIANO ONLY_basic_pitch.mid")

# Environment variables
n_shingle = 3
round_place = 0

# %%
# Generate graphs
std_onset = 0.5;
std_frame = 0.3;
std_min_note_len = 127.70
std_min_freq = None;
std_max_freq = None;

def generate_similarity(onset, frame, min_note_len, min_freq, max_freq):
    model_output, midi_data, note_events = predict(
        "C:\\Users\\Tim\\Documents\\GitHub\\purdue-AIMA-basic-pitch-testing\\Tim\'s songs\\Blind Composition Render\\blind comp render E-PIANO ONLY.mp3",
        basic_pitch_model,
        onset,
        frame,
        min_note_len,
        min_freq,
        max_freq
    );
    return similarityPitchedDual(midi, midi_data, n_shingle, round_place, False)

def plot(in_vals, out_vals, title, axis_in, axis_out):
    fig, ax = plt.subplots()
    ax.plot(in_vals, out_vals)
    ax.set_xlabel(axis_in)
    ax.set_ylabel(axis_out)
    ax.set_title(title)
    ax.grid(True)
    plt.show()

def generate_arrays():
    # onset vary
    in_vals = list(np.linspace(0.01, 0.05 * 20 + 0.01, 20))
    out_vals = []
    for i in in_vals:
        out_vals.append(generate_similarity(i, std_frame, std_min_note_len, std_min_freq, std_max_freq))
    plot(in_vals, out_vals, "Varying onset", "Onset coeff.", "Note similarity")
    
    # frame vary
    in_vals = list(np.linspace(0.01, 0.05 * 20 + 0.01, 20))
    out_vals = []
    for i in in_vals:
        out_vals = generate_similarity(std_onset, i, std_min_note_len, std_min_freq, std_max_freq)
    plot(in_vals, out_vals, "Varying frames", "Frame coeff.", "Note similarity")
        
    # min_note_len vary
    in_vals = list(np.linspace(5, 10 * 20 + 5, 20))
    out_vals = []
    for i in in_vals:
        out_vals = generate_similarity(std_onset, std_frame, i, std_min_freq, std_max_freq)
    plot(in_vals, out_vals, "Varying minimum note length", "Minimum note length (ms)", "Note similarity")
        
    # min_freq vary
    in_vals = list(np.linspace(0, 20 * 20, 20))
    out_vals = []
    for i in in_vals:
        out_vals = generate_similarity(std_onset, std_frame, std_min_note_len, i, std_max_freq)
    plot(in_vals, out_vals, "Varying minimum freq.", "Min. freq. (Hz)", "Note similarity")
        
    # max_freq vary
    in_vals = list(np.linspace(10000, -400 * 20 + 10000, 20))
    out_vals = []
    for i in in_vals:
        out_vals = generate_similarity(std_onset, std_frame, std_min_note_len, std_min_freq, i)
    plot(in_vals, out_vals, "Varying maximum freq.", "Max. freq. (Hz)", "Note similarity")

# %%
def generate_arrays():
    # onset vary
    in_vals = list(np.linspace(0.01, 0.05 * 20 + 0.01, 20))
    out_vals = []
    for i in in_vals:
        out_vals.append(generate_similarity(i, std_frame, std_min_note_len, std_min_freq, std_max_freq))
    plot(in_vals, out_vals, "Varying onset", "Onset coeff.", "Note similarity")

# %%
generate_arrays()
# Out:
# Predicting MIDI for C:\Users\Tim\Documents\GitHub\purdue-AIMA-basic-pitch-testing\Tim's songs\Blind Composition Render\blind comp render E-PIANO ONLY.mp3...

# %%
model_output, midi_data, note_events = predict(
        "C:\\Users\\Tim\\Documents\\GitHub\\purdue-AIMA-basic-pitch-testing\\Tim\'s songs\\Blind Composition Render\\blind comp render E-PIANO ONLY.mp3",
        basic_pitch_model,
        std_onset,
        std_frame,
        std_min_note_len,
        std_min_freq,
        _stdmax_freq
    );

# %%
generate_similarity(std_onset, std_frame, std_min_note_len, std_min_freq, std_max_freq)
# Out:
# Predicting MIDI for C:\Users\Tim\Documents\GitHub\purdue-AIMA-basic-pitch-testing\Tim's songs\Blind Composition Render\blind comp render E-PIANO ONLY.mp3...
# 2.0972394005097565

# %%
similarityPitchedDual(midi, temp_data, n_shingle, round_place, False)
# Out:
# 2.0972394005097565

# %%
temp_data.instruments[0].notes
# Out:
# [Note(start=0.928798, end=1.102948, pitch=47, velocity=35),
#  Note(start=1.509297, end=1.998200, pitch=28, velocity=63),
#  Note(start=2.903778, end=3.066318, pitch=28, velocity=46),
#  Note(start=3.077928, end=3.774527, pitch=28, velocity=67),
#  Note(start=4.960028, end=5.749507, pitch=28, velocity=75),
#  Note(start=8.387539, end=8.851938, pitch=28, velocity=66),
#  Note(start=9.908446, end=10.606329, pitch=28, velocity=66),
#  Note(start=11.302927, end=11.639617, pitch=33, velocity=51),
#  Note(start=11.639617, end=11.790546, pitch=33, velocity=54),
#  Note(start=11.836986, end=12.395549, pitch=31, velocity=57),
#  Note(start=13.765527, end=14.649169, pitch=64, velocity=93),
#  Note(start=13.765527, end=14.707219, pitch=40, velocity=73),
#  Note(start=13.777137, end=14.312479, pitch=71, velocity=44),
#  Note(start=13.777137, end=14.614339, pitch=52, velocity=57),
#  Note(start=13.777137, end=14.625949, pitch=67, velocity=78),
#  Note(start=13.788746, end=14.521459, pitch=79, velocity=54),
#  Note(start=14.834928, end=15.136788, pitch=40, velocity=54),
#  Note(start=14.846538, end=14.997468, pitch=71, velocity=40),
#  Note(start=14.846538, end=15.009078, pitch=52, velocity=63),
#  Note(start=14.846538, end=15.043908, pitch=66, velocity=87),
#  Note(start=15.043908, end=15.264498, pitch=67, velocity=98),
#  Note(start=15.264498, end=15.496697, pitch=62, velocity=38),
#  Note(start=15.264498, end=16.275849, pitch=74, velocity=61),
#  Note(start=15.264498, end=16.322289, pitch=66, velocity=75),
#  Note(start=15.264498, end=16.333899, pitch=69, velocity=94),
#  Note(start=15.264498, end=16.415169, pitch=50, velocity=62),
#  Note(start=15.264498, end=16.438389, pitch=38, velocity=85),
#  Note(start=15.334157, end=15.891436, pitch=78, velocity=48),
#  Note(start=16.542879, end=16.751859, pitch=74, velocity=60),
#  Note(start=16.542879, end=16.856348, pitch=38, velocity=64),
#  Note(start=16.554489, end=16.786688, pitch=67, velocity=91),
#  Note(start=16.554489, end=16.844738, pitch=50, velocity=64),
#  Note(start=16.763468, end=16.995668, pitch=69, velocity=92),
#  Note(start=16.972448, end=17.367187, pitch=76, velocity=60),
#  Note(start=16.972448, end=17.425237, pitch=71, velocity=83),
#  Note(start=16.972448, end=17.937360, pitch=67, velocity=54),
#  Note(start=16.972448, end=18.146340, pitch=37, velocity=88),
#  Note(start=16.984058, end=17.158208, pitch=49, velocity=40),
#  Note(start=16.984058, end=17.402017, pitch=64, velocity=72),
#  Note(start=16.984058, end=17.413627, pitch=61, velocity=62),
#  Note(start=17.402017, end=18.262439, pitch=64, velocity=100),
#  Note(start=17.413627, end=17.960580, pitch=61, velocity=47),
#  Note(start=17.448457, end=17.703877, pitch=49, velocity=50),
#  Note(start=18.250829, end=18.448199, pitch=76, velocity=64),
#  Note(start=18.250829, end=18.541079, pitch=37, velocity=59),
#  Note(start=18.262439, end=18.401759, pitch=49, velocity=45),
#  Note(start=18.262439, end=18.436589, pitch=73, velocity=62),
#  Note(start=18.262439, end=18.448199, pitch=61, velocity=65),
#  Note(start=18.262439, end=18.471419, pitch=64, velocity=79),
#  Note(start=18.262439, end=18.471419, pitch=67, velocity=71),
#  Note(start=18.471419, end=18.715229, pitch=62, velocity=91),
#  Note(start=18.692009, end=18.900988, pitch=64, velocity=102),
#  Note(start=18.900988, end=19.307337, pitch=60, velocity=61),
#  Note(start=18.900988, end=19.330557, pitch=64, velocity=93),
#  Note(start=18.900988, end=19.458267, pitch=67, velocity=58),
#  Note(start=18.900988, end=19.458267, pitch=72, velocity=51),
#  Note(start=18.900988, end=19.678857, pitch=36, velocity=78),
#  Note(start=18.912598, end=19.527927, pitch=48, velocity=68),
#  Note(start=19.330557, end=19.551147, pitch=64, velocity=46),
#  Note(start=19.330557, end=19.562757, pitch=62, velocity=85),
#  Note(start=19.551147, end=19.783346, pitch=64, velocity=93),
#  Note(start=19.760127, end=20.539279, pitch=38, velocity=81),
#  Note(start=19.771737, end=20.121320, pitch=69, velocity=50),
#  Note(start=19.771737, end=20.190980, pitch=50, velocity=71),
#  Note(start=19.771737, end=20.190980, pitch=62, velocity=53),
#  Note(start=19.771737, end=20.202590, pitch=66, velocity=100),
#  Note(start=20.190980, end=20.341909, pitch=69, velocity=40),
#  Note(start=20.190980, end=20.376739, pitch=62, velocity=54),
#  Note(start=20.190980, end=20.458009, pitch=50, velocity=59),
#  Note(start=20.202590, end=20.411569, pitch=66, velocity=102),
#  Note(start=20.411569, end=20.620549, pitch=66, velocity=92),
#  Note(start=20.608939, end=21.572567, pitch=40, velocity=71),
#  Note(start=20.620549, end=21.398417, pitch=71, velocity=42),
#  Note(start=20.620549, end=21.479687, pitch=67, velocity=77),
#  Note(start=20.620549, end=21.502907, pitch=52, velocity=57),
#  Note(start=20.620549, end=21.526127, pitch=64, velocity=94),
#  Note(start=20.643769, end=21.386807, pitch=79, velocity=54),
#  Note(start=21.688667, end=21.980200, pitch=40, velocity=52),
#  Note(start=21.700277, end=21.851206, pitch=71, velocity=41),
#  Note(start=21.700277, end=21.864100, pitch=52, velocity=61),
#  Note(start=21.700277, end=21.898930, pitch=67, velocity=56),
#  Note(start=21.898930, end=22.119520, pitch=67, velocity=96),
#  Note(start=22.107910, end=22.363329, pitch=81, velocity=41),
#  Note(start=22.107910, end=22.711629, pitch=78, velocity=41),
#  Note(start=22.107910, end=23.210858, pitch=69, velocity=90),
#  Note(start=22.107910, end=23.292127, pitch=38, velocity=83),
#  Note(start=22.119520, end=23.129588, pitch=74, velocity=53),
#  Note(start=22.119520, end=23.152808, pitch=66, velocity=66),
#  Note(start=22.119520, end=23.419837, pitch=50, velocity=63),
#  Note(start=23.396617, end=23.605597, pitch=38, velocity=68),
#  Note(start=23.419837, end=23.582377, pitch=62, velocity=46),
#  Note(start=23.419837, end=23.628817, pitch=67, velocity=84),
#  Note(start=23.419837, end=23.721697, pitch=50, velocity=65),
#  Note(start=23.605597, end=23.744917, pitch=38, velocity=61),
#  Note(start=23.617207, end=23.839080, pitch=69, velocity=94),
#  Note(start=23.837796, end=24.233820, pitch=78, velocity=77),
#  Note(start=23.837796, end=24.245429, pitch=60, velocity=75),
#  Note(start=23.837796, end=24.245429, pitch=67, velocity=84),
#  Note(start=23.837796, end=24.245429, pitch=71, velocity=89),
#  Note(start=23.837796, end=24.268649, pitch=52, velocity=65),
#  Note(start=23.839080, end=24.129330, pitch=45, velocity=48),
#  Note(start=23.850690, end=25.510917, pitch=33, velocity=90),
#  Note(start=24.245429, end=24.686609, pitch=76, velocity=102),
#  Note(start=24.245429, end=24.698219, pitch=67, velocity=74),
#  Note(start=24.245429, end=24.814318, pitch=72, velocity=53),
#  Note(start=24.245429, end=25.325157, pitch=60, velocity=87),
#  Note(start=24.257039, end=24.686609, pitch=64, velocity=46),
#  Note(start=24.326699, end=25.267107, pitch=45, velocity=59),
#  Note(start=24.686609, end=25.290327, pitch=64, velocity=57),
#  Note(start=24.686609, end=25.313547, pitch=76, velocity=89),
#  Note(start=25.336767, end=25.568967, pitch=71, velocity=97),
#  Note(start=25.545747, end=25.766337, pitch=69, velocity=103),
#  Note(start=25.743117, end=26.510659, pitch=33, velocity=81),
#  Note(start=25.754727, end=26.104310, pitch=72, velocity=50),
#  Note(start=25.766337, end=26.139140, pitch=64, velocity=55),
#  Note(start=25.766337, end=26.173970, pitch=60, velocity=61),
#  Note(start=25.766337, end=26.173970, pitch=69, velocity=91),
#  Note(start=25.766337, end=26.185580, pitch=67, velocity=48),
#  Note(start=25.766337, end=26.348119, pitch=45, velocity=49),
#  Note(start=26.173970, end=26.336509, pitch=72, velocity=46),
#  Note(start=26.173970, end=26.371339, pitch=60, velocity=57),
#  Note(start=26.185580, end=26.348119, pitch=64, velocity=48),
#  Note(start=26.185580, end=26.417779, pitch=67, velocity=92),
#  Note(start=26.406169, end=26.661589, pitch=69, velocity=90),
#  Note(start=26.615149, end=26.870568, pitch=71, velocity=96),
#  Note(start=26.615149, end=27.021498, pitch=74, velocity=51),
#  Note(start=26.615149, end=27.044718, pitch=62, velocity=65),
#  Note(start=26.615149, end=27.497507, pitch=35, velocity=85),
#  Note(start=26.626759, end=26.951838, pitch=47, velocity=48),
#  Note(start=26.626759, end=27.044718, pitch=66, velocity=61),
#  Note(start=26.812518, end=27.009888, pitch=78, velocity=56),
#  Note(start=26.835738, end=27.033108, pitch=69, velocity=76),
#  Note(start=27.044718, end=27.393017, pitch=66, velocity=43),
#  Note(start=27.044718, end=27.416237, pitch=62, velocity=66),
#  Note(start=27.044718, end=27.497507, pitch=71, velocity=101),
#  Note(start=27.102768, end=27.393017, pitch=47, velocity=49),
#  Note(start=27.462677, end=28.555299, pitch=40, velocity=72),
#  Note(start=27.474287, end=28.114120, pitch=79, velocity=104),
#  Note(start=27.474287, end=28.265049, pitch=67, velocity=62),
#  Note(start=27.485897, end=28.056070, pitch=64, velocity=48),
#  Note(start=27.485897, end=28.288269, pitch=52, velocity=63),
#  Note(start=28.114120, end=28.288269, pitch=59, velocity=52),
#  Note(start=28.114120, end=28.369539, pitch=78, velocity=96),
#  Note(start=28.555299, end=28.694619, pitch=71, velocity=33),
#  Note(start=28.555299, end=28.729449, pitch=79, velocity=58),
#  Note(start=28.555299, end=28.752668, pitch=52, velocity=63),
#  Note(start=28.555299, end=28.787498, pitch=67, velocity=68),
#  Note(start=28.555299, end=28.903598, pitch=40, velocity=83),
#  Note(start=28.555299, end=29.996220, pitch=74, velocity=73),
#  Note(start=28.973258, end=29.217068, pitch=62, velocity=36),
#  Note(start=28.973258, end=30.031050, pitch=50, velocity=66),
#  Note(start=28.973258, end=30.042660, pitch=69, velocity=96),
#  Note(start=28.973258, end=30.147150, pitch=38, velocity=85),
#  Note(start=28.984868, end=30.054270, pitch=66, velocity=75),
#  Note(start=29.042918, end=29.727907, pitch=78, velocity=48),
#  Note(start=30.031050, end=30.263249, pitch=50, velocity=42),
#  Note(start=30.042660, end=30.251639, pitch=69, velocity=92),
#  Note(start=30.251639, end=30.460619, pitch=69, velocity=75),
#  Note(start=30.251639, end=30.460619, pitch=74, velocity=77),
#  Note(start=30.251639, end=30.460619, pitch=78, velocity=71),
#  Note(start=30.263249, end=30.449009, pitch=38, velocity=76),
#  Note(start=30.263249, end=30.449009, pitch=62, velocity=55),
#  Note(start=30.263249, end=30.460619, pitch=50, velocity=73),
#  Note(start=30.263249, end=30.495449, pitch=66, velocity=71),
#  Note(start=30.449009, end=30.599939, pitch=38, velocity=74),
#  Note(start=30.472229, end=30.716039, pitch=71, velocity=96),
#  Note(start=30.681209, end=30.855358, pitch=49, velocity=49),
#  Note(start=30.681209, end=30.878578, pitch=73, velocity=59),
#  Note(start=30.681209, end=30.901798, pitch=76, velocity=63),
#  Note(start=30.681209, end=31.843490, pitch=37, velocity=86),
#  Note(start=30.692819, end=30.901798, pitch=64, velocity=84),
#  Note(start=30.692819, end=30.901798, pitch=67, velocity=76),
#  Note(start=30.692819, end=31.505517, pitch=61, velocity=51),
#  Note(start=30.890188, end=31.366197, pitch=79, velocity=97),
#  Note(start=30.901798, end=31.517127, pitch=67, velocity=63),
#  Note(start=30.901798, end=31.702887, pitch=64, velocity=74),
#  Note(start=31.331367, end=31.470687, pitch=76, velocity=49),
#  Note(start=31.551957, end=31.808660, pitch=78, velocity=103),
#  Note(start=31.959590, end=32.156960, pitch=37, velocity=74),
#  Note(start=31.971200, end=32.133740, pitch=49, velocity=46),
#  Note(start=31.971200, end=32.145350, pitch=67, velocity=51),
#  Note(start=31.982810, end=32.122130, pitch=61, velocity=58),
#  Note(start=31.982810, end=32.238229, pitch=64, velocity=85),
#  Note(start=31.982810, end=32.238229, pitch=74, velocity=87),
#  Note(start=32.156960, end=32.342719, pitch=37, velocity=74),
#  Note(start=32.389159, end=33.248298, pitch=81, velocity=96),
#  Note(start=32.609749, end=33.201858, pitch=76, velocity=58),
#  Note(start=32.609749, end=33.225078, pitch=72, velocity=68),
#  Note(start=32.609749, end=33.364397, pitch=36, velocity=81),
#  Note(start=32.621359, end=33.213468, pitch=64, velocity=63),
#  Note(start=32.621359, end=33.248298, pitch=48, velocity=81),
#  Note(start=33.259907, end=33.480497, pitch=79, velocity=102),
#  Note(start=33.468887, end=34.224820, pitch=38, velocity=80),
#  Note(start=33.480497, end=33.689477, pitch=50, velocity=73),
#  Note(start=33.480497, end=33.689477, pitch=66, velocity=67),
#  Note(start=33.480497, end=33.689477, pitch=74, velocity=74),
#  Note(start=33.480497, end=33.689477, pitch=79, velocity=93),
#  Note(start=33.480497, end=33.853300, pitch=69, velocity=59),
#  Note(start=33.689477, end=33.830080, pitch=62, velocity=34),
#  Note(start=33.689477, end=33.864910, pitch=74, velocity=64),
#  Note(start=33.689477, end=33.899740, pitch=66, velocity=58),
#  Note(start=33.689477, end=33.911350, pitch=78, velocity=92),
#  Note(start=33.689477, end=34.050670, pitch=50, velocity=69),
#  Note(start=33.888130, end=34.120330, pitch=76, velocity=90),
#  Note(start=33.899740, end=34.108720, pitch=66, velocity=79),
#  Note(start=34.108720, end=34.340919, pitch=74, velocity=94),
#  Note(start=34.317699, end=35.188448, pitch=76, velocity=105),
#  Note(start=34.317699, end=35.316157, pitch=40, velocity=76),
#  Note(start=34.329309, end=34.828538, pitch=64, velocity=48),
#  Note(start=34.329309, end=35.142008, pitch=71, velocity=51),
#  Note(start=34.329309, end=35.176838, pitch=52, velocity=60),
#  Note(start=34.329309, end=35.211668, pitch=67, velocity=86),
#  Note(start=35.188448, end=35.409037, pitch=76, velocity=83),
#  Note(start=35.397427, end=35.594797, pitch=40, velocity=67),
#  Note(start=35.409037, end=35.559967, pitch=59, velocity=52),
#  Note(start=35.409037, end=35.559967, pitch=71, velocity=48),
#  Note(start=35.409037, end=35.583187, pitch=52, velocity=63),
#  Note(start=35.409037, end=35.618017, pitch=67, velocity=67),
#  Note(start=35.409037, end=35.618017, pitch=78, velocity=88),
#  Note(start=35.594797, end=35.734117, pitch=40, velocity=60),
#  Note(start=35.618017, end=35.839890, pitch=79, velocity=97),
#  Note(start=35.816670, end=37.082158, pitch=81, velocity=84),
#  Note(start=35.816670, end=37.116988, pitch=38, velocity=79),
#  Note(start=35.828280, end=36.838348, pitch=62, velocity=43),
#  Note(start=35.828280, end=36.873178, pitch=66, velocity=75),
#  Note(start=35.828280, end=36.884788, pitch=69, velocity=59),
#  Note(start=35.828280, end=36.942838, pitch=50, velocity=67),
#  Note(start=35.851500, end=36.815128, pitch=74, velocity=46),
#  Note(start=37.116988, end=37.314357, pitch=38, velocity=75),
#  Note(start=37.116988, end=37.314357, pitch=66, velocity=66),
#  Note(start=37.116988, end=37.314357, pitch=69, velocity=74),
#  Note(start=37.116988, end=37.349187, pitch=79, velocity=92),
#  Note(start=37.128598, end=37.267917, pitch=62, velocity=40),
#  Note(start=37.128598, end=37.302747, pitch=74, velocity=61),
#  Note(start=37.128598, end=37.395627, pitch=50, velocity=64),
#  Note(start=37.314357, end=37.476897, pitch=38, velocity=70),
#  Note(start=37.325967, end=37.558167, pitch=81, velocity=97),
#  Note(start=37.534947, end=37.989020, pitch=83, velocity=97),
#  Note(start=37.546557, end=37.732317, pitch=33, velocity=75),
#  Note(start=37.546557, end=37.942580, pitch=79, velocity=65),
#  Note(start=37.546557, end=37.965800, pitch=60, velocity=72),
#  Note(start=37.546557, end=37.965800, pitch=64, velocity=62),
#  Note(start=37.546557, end=37.965800, pitch=67, velocity=75),
#  Note(start=37.558167, end=38.151560, pitch=45, velocity=59),
#  Note(start=37.581387, end=37.720707, pitch=48, velocity=49),
#  Note(start=37.732317, end=39.208068, pitch=33, velocity=90),
#  Note(start=37.965800, end=38.395369, pitch=64, velocity=47),
#  Note(start=37.965800, end=38.395369, pitch=76, velocity=103),
#  Note(start=37.965800, end=38.418589, pitch=67, velocity=77),
#  Note(start=37.965800, end=38.534689, pitch=72, velocity=54),
#  Note(start=37.965800, end=39.033918, pitch=60, velocity=88),
#  Note(start=38.395369, end=38.824938, pitch=76, velocity=93),
#  Note(start=38.395369, end=38.999088, pitch=64, velocity=57),
#  Note(start=38.406979, end=38.975868, pitch=45, velocity=61),
#  Note(start=38.824938, end=39.010698, pitch=76, velocity=75),
#  Note(start=39.045528, end=39.277727, pitch=74, velocity=95),
#  Note(start=39.254507, end=39.475097, pitch=76, velocity=107),
#  Note(start=39.463487, end=40.231029, pitch=33, velocity=80),
#  Note(start=39.475097, end=39.882730, pitch=72, velocity=76),
#  Note(start=39.475097, end=39.882730, pitch=76, velocity=85),
#  Note(start=39.486707, end=39.649247, pitch=48, velocity=57),
#  Note(start=39.486707, end=39.778240, pitch=45, velocity=48),
#  Note(start=39.486707, end=39.894340, pitch=67, velocity=83),
#  Note(start=39.486707, end=39.905950, pitch=60, velocity=71),
#  Note(start=39.486707, end=39.905950, pitch=64, velocity=62),
#  Note(start=39.894340, end=40.068490, pitch=67, velocity=57),
#  Note(start=39.894340, end=40.126540, pitch=74, velocity=89),
#  Note(start=39.905950, end=40.091710, pitch=60, velocity=63),
#  Note(start=39.905950, end=40.149760, pitch=64, velocity=74),
#  Note(start=40.114930, end=40.347129, pitch=76, velocity=98),
#  Note(start=40.312299, end=41.171438, pitch=35, velocity=90),
#  Note(start=40.323909, end=40.753478, pitch=74, velocity=65),
#  Note(start=40.323909, end=40.753478, pitch=78, velocity=94),
#  Note(start=40.335519, end=40.486449, pitch=50, velocity=65),
#  Note(start=40.335519, end=40.556109, pitch=47, velocity=43),
#  Note(start=40.335519, end=40.718649, pitch=66, velocity=54),
#  Note(start=40.335519, end=40.753478, pitch=62, velocity=67),
#  Note(start=40.335519, end=41.136608, pitch=69, velocity=71),
#  Note(start=40.753478, end=41.136608, pitch=66, velocity=51),
#  Note(start=40.753478, end=41.148218, pitch=62, velocity=69),
#  Note(start=40.753478, end=41.148218, pitch=74, velocity=62),
#  Note(start=40.753478, end=41.206268, pitch=78, velocity=99),
#  Note(start=41.008898, end=41.159828, pitch=50, velocity=65),
#  Note(start=41.206268, end=41.415247, pitch=52, velocity=60),
#  Note(start=41.217878, end=41.473297, pitch=40, velocity=70),
#  Note(start=41.473297, end=41.624227, pitch=40, velocity=36),
#  Note(start=41.612617, end=41.904150, pitch=79, velocity=74),
#  Note(start=41.624227, end=41.834490, pitch=40, velocity=70),
#  Note(start=41.624227, end=41.880930, pitch=76, velocity=61),
#  Note(start=41.624227, end=41.892540, pitch=52, velocity=59),
#  Note(start=41.624227, end=41.904150, pitch=71, velocity=54),
#  Note(start=41.624227, end=41.927370, pitch=64, velocity=56),
#  Note(start=41.624227, end=41.938980, pitch=67, velocity=71),
#  Note(start=42.693629, end=43.123198, pitch=50, velocity=69),
#  Note(start=42.705239, end=43.146418, pitch=38, velocity=83),
#  Note(start=43.123198, end=43.332177, pitch=50, velocity=37),
#  Note(start=43.146418, end=43.320567, pitch=38, velocity=43),
#  Note(start=43.320567, end=43.564377, pitch=38, velocity=67),
#  Note(start=43.332177, end=43.622427, pitch=78, velocity=59),
#  Note(start=43.332177, end=43.645647, pitch=74, velocity=78),
#  Note(start=43.332177, end=43.657257, pitch=50, velocity=75),
#  Note(start=43.343787, end=43.645647, pitch=66, velocity=48),
#  Note(start=43.343787, end=43.645647, pitch=69, velocity=59),
#  Note(start=44.401579, end=44.540899, pitch=61, velocity=58),
#  Note(start=44.401579, end=44.540899, pitch=91, velocity=55),
#  Note(start=44.401579, end=44.587339, pitch=76, velocity=48),
#  Note(start=44.401579, end=44.610559, pitch=64, velocity=64),
#  Note(start=44.401579, end=44.633779, pitch=67, velocity=88),
#  Note(start=44.482849, end=44.633779, pitch=49, velocity=58),
#  Note(start=44.645389, end=44.796318, pitch=49, velocity=55),
#  Note(start=44.656999, end=44.865978, pitch=37, velocity=73),
#  Note(start=45.074958, end=45.225888, pitch=49, velocity=52),
#  Note(start=45.074958, end=45.295547, pitch=37, velocity=75),
#  Note(start=46.109530, end=46.353339, pitch=82, velocity=65),
#  Note(start=46.109530, end=46.422999, pitch=78, velocity=67),
#  Note(start=46.121140, end=46.364949, pitch=66, velocity=71),
#  Note(start=46.121140, end=46.364949, pitch=73, velocity=81),
#  Note(start=46.121140, end=46.376559, pitch=70, velocity=73),
#  Note(start=46.190800, end=46.434609, pitch=54, velocity=51),
#  Note(start=46.353339, end=46.713249, pitch=30, velocity=67),
#  Note(start=46.364949, end=46.782908, pitch=42, velocity=73),
#  Note(start=46.782908, end=46.980278, pitch=54, velocity=50),
#  Note(start=46.782908, end=47.049938, pitch=42, velocity=79),
#  Note(start=46.968668, end=47.142818, pitch=82, velocity=32),
#  Note(start=46.968668, end=47.166038, pitch=78, velocity=45),
#  Note(start=46.980278, end=47.131208, pitch=54, velocity=44),
#  Note(start=47.049938, end=47.189258, pitch=42, velocity=59),
#  Note(start=47.189258, end=47.375017, pitch=53, velocity=49),
#  Note(start=47.189258, end=47.607217, pitch=77, velocity=56),
#  Note(start=47.224088, end=47.642047, pitch=41, velocity=70),
#  Note(start=47.258917, end=47.525947, pitch=29, velocity=62),
#  Note(start=47.642047, end=47.805870, pitch=53, velocity=65),
#  Note(start=47.642047, end=47.991630, pitch=41, velocity=64),
#  Note(start=48.049680, end=48.247049, pitch=52, velocity=55),
#  Note(start=48.084510, end=48.293489, pitch=40, velocity=69),
#  Note(start=48.467639, end=48.688229, pitch=40, velocity=66),
#  Note(start=48.467639, end=48.734668, pitch=76, velocity=58),
#  Note(start=48.467639, end=48.769498, pitch=79, velocity=72),
#  Note(start=48.479249, end=48.769498, pitch=52, velocity=57),
#  Note(start=48.479249, end=48.769498, pitch=64, velocity=54),
#  Note(start=48.479249, end=48.769498, pitch=71, velocity=54),
#  Note(start=48.479249, end=48.804328, pitch=67, velocity=70),
#  Note(start=49.558977, end=50.036270, pitch=50, velocity=69),
#  Note(start=49.593807, end=50.001440, pitch=38, velocity=80),
#  Note(start=50.175590, end=50.489059, pitch=81, velocity=67),
#  Note(start=50.187200, end=50.442619, pitch=38, velocity=72),
#  Note(start=50.187200, end=50.454229, pitch=66, velocity=47),
#  Note(start=50.187200, end=50.454229, pitch=78, velocity=55),
#  Note(start=50.187200, end=50.500669, pitch=62, velocity=44),
#  Note(start=50.187200, end=50.500669, pitch=69, velocity=55),
#  Note(start=50.187200, end=50.535499, pitch=50, velocity=66),
#  Note(start=50.198810, end=50.465839, pitch=74, velocity=58),
#  Note(start=51.139218, end=51.278537, pitch=28, velocity=44),
#  Note(start=51.255317, end=51.533957, pitch=83, velocity=73),
#  Note(start=51.266927, end=51.499127, pitch=64, velocity=72),
#  Note(start=51.266927, end=51.522347, pitch=67, velocity=76),
#  Note(start=51.266927, end=51.638447, pitch=60, velocity=65),
#  Note(start=51.278537, end=52.057690, pitch=78, velocity=60),
#  Note(start=51.359807, end=51.499127, pitch=45, velocity=67),
#  Note(start=51.510737, end=51.686171, pitch=45, velocity=65),
#  Note(start=51.545567, end=51.964810, pitch=33, velocity=56),
#  Note(start=51.686171, end=51.941590, pitch=45, velocity=48),
#  Note(start=51.686171, end=52.022860, pitch=83, velocity=55),
#  Note(start=51.732610, end=52.069300, pitch=67, velocity=62),
#  Note(start=51.825490, end=52.034470, pitch=72, velocity=45),
#  Note(start=51.837100, end=52.104130, pitch=60, velocity=44),
#  Note(start=51.941590, end=52.115740, pitch=45, velocity=60),
#  Note(start=51.964810, end=52.127350, pitch=33, velocity=70),
#  Note(start=52.104130, end=52.278279, pitch=72, velocity=53),
#  Note(start=52.104130, end=52.359549, pitch=83, velocity=46),
#  Note(start=52.104130, end=52.719459, pitch=64, velocity=60),
#  Note(start=52.104130, end=52.731068, pitch=76, velocity=84),
#  Note(start=52.115740, end=52.464039, pitch=45, velocity=51),
#  Note(start=52.115740, end=52.719459, pitch=60, velocity=66),
#  Note(start=52.324719, end=52.498869, pitch=33, velocity=39),
#  Note(start=52.464039, end=52.731068, pitch=45, velocity=54),
#  Note(start=52.777508, end=52.916828, pitch=33, velocity=45),
#  Note(start=53.183858, end=53.613427, pitch=79, velocity=66),
#  Note(start=53.183858, end=53.637931, pitch=36, velocity=68),
#  Note(start=53.195468, end=53.578597, pitch=76, velocity=45),
#  Note(start=53.195468, end=53.590207, pitch=64, velocity=51),
#  Note(start=53.195468, end=53.625037, pitch=60, velocity=49),
#  Note(start=53.195468, end=53.625037, pitch=67, velocity=53),
#  Note(start=53.637931, end=53.835300, pitch=48, velocity=67),
#  Note(start=53.637931, end=53.858520, pitch=36, velocity=74),
#  Note(start=54.032670, end=54.195210, pitch=69, velocity=42),
#  Note(start=54.032670, end=54.206820, pitch=78, velocity=45),
#  Note(start=54.032670, end=54.230039, pitch=50, velocity=43),
#  Note(start=54.032670, end=54.450629, pitch=74, velocity=51),
#  Note(start=54.079110, end=54.497069, pitch=38, velocity=70),
#  Note(start=54.497069, end=54.659609, pitch=50, velocity=60),
#  Note(start=54.497069, end=54.717659, pitch=38, velocity=83),
#  Note(start=54.717659, end=54.856978, pitch=38, velocity=50),
#  Note(start=54.915028, end=55.158838, pitch=52, velocity=49),
#  Note(start=55.019518, end=55.182058, pitch=40, velocity=63),
#  Note(start=55.356207, end=55.507137, pitch=52, velocity=50),
#  Note(start=55.356207, end=55.600017, pitch=40, velocity=72),
#  Note(start=55.600017, end=55.845110, pitch=40, velocity=41),
#  Note(start=55.787060, end=55.949600, pitch=52, velocity=35),
#  Note(start=56.193410, end=56.367559, pitch=52, velocity=62),
#  Note(start=56.402389, end=56.878398, pitch=50, velocity=69),
#  Note(start=56.413999, end=56.855178, pitch=38, velocity=69),
#  Note(start=57.040938, end=57.215088, pitch=78, velocity=45),
#  Note(start=57.040938, end=57.342797, pitch=74, velocity=60),
#  Note(start=57.040938, end=57.377627, pitch=50, velocity=67),
#  Note(start=57.064158, end=57.319577, pitch=38, velocity=66),
#  Note(start=57.366017, end=57.598217, pitch=52, velocity=41),
#  Note(start=57.598217, end=57.796870, pitch=52, velocity=38),
#  Note(start=57.796870, end=58.005850, pitch=52, velocity=54),
#  Note(start=58.005850, end=58.226439, pitch=52, velocity=43),
#  Note(start=58.110340, end=58.249659, pitch=61, velocity=52),
#  Note(start=58.110340, end=58.296099, pitch=76, velocity=48),
#  Note(start=58.110340, end=58.342539, pitch=67, velocity=86),
#  Note(start=58.121950, end=58.296099, pitch=64, velocity=50),
#  Note(start=58.226439, end=58.365759, pitch=52, velocity=61),
#  Note(start=58.354149, end=58.493469, pitch=49, velocity=55),
#  Note(start=58.365759, end=58.539909, pitch=52, velocity=61),
#  Note(start=58.365759, end=58.563129, pitch=37, velocity=65),
#  Note(start=58.783718, end=58.923038, pitch=49, velocity=48),
#  Note(start=58.783718, end=59.004308, pitch=37, velocity=60),
#  Note(start=58.806938, end=58.957868, pitch=52, velocity=57),
#  Note(start=59.190068, end=59.387437, pitch=52, velocity=47),
#  Note(start=59.620921, end=59.795070, pitch=52, velocity=58),
#  Note(start=59.818290, end=60.050490, pitch=82, velocity=58),
#  Note(start=59.818290, end=60.096930, pitch=54, velocity=46),
#  Note(start=59.829900, end=60.050490, pitch=66, velocity=61),
#  Note(start=59.829900, end=60.050490, pitch=73, velocity=69),
#  Note(start=59.829900, end=60.062100, pitch=70, velocity=63),
#  Note(start=59.829900, end=60.108540, pitch=78, velocity=62),
#  Note(start=60.062100, end=60.596159, pitch=42, velocity=65),
#  Note(start=60.085320, end=60.398789, pitch=30, velocity=62),
#  Note(start=60.491669, end=60.700649, pitch=54, velocity=46),
#  Note(start=60.596159, end=60.758698, pitch=42, velocity=63),
#  Note(start=60.689039, end=60.874798, pitch=78, velocity=39),
#  Note(start=60.700649, end=60.839968, pitch=54, velocity=43),
#  Note(start=60.758698, end=60.898018, pitch=42, velocity=57),
#  Note(start=60.898018, end=61.304367, pitch=77, velocity=48),
#  Note(start=60.909628, end=61.350807, pitch=53, velocity=45),
#  Note(start=60.932848, end=61.362417, pitch=41, velocity=57),
#  Note(start=60.990898, end=61.199878, pitch=29, velocity=57),
#  Note(start=61.350807, end=61.524957, pitch=53, velocity=57),
#  Note(start=61.362417, end=61.584291, pitch=41, velocity=75),
#  Note(start=61.781660, end=61.979030, pitch=52, velocity=48),
#  Note(start=61.793270, end=61.990640, pitch=40, velocity=67),
#  Note(start=62.188010, end=62.338939, pitch=55, velocity=57),
#  Note(start=62.188010, end=62.408599, pitch=52, velocity=50),
#  Note(start=62.188010, end=62.431819, pitch=40, velocity=69),
#  Note(start=62.617579, end=62.791728, pitch=52, velocity=59),
#  Note(start=63.058758, end=63.221298, pitch=52, velocity=58),
#  Note(start=63.267737, end=63.745030, pitch=50, velocity=64),
#  Note(start=63.302567, end=63.710200, pitch=38, velocity=67),
#  Note(start=63.884350, end=64.186210, pitch=81, velocity=45),
#  Note(start=63.895960, end=64.209429, pitch=50, velocity=60),
#  Note(start=63.919180, end=64.151380, pitch=38, velocity=67),
#  Note(start=64.221039, end=64.441629, pitch=52, velocity=43),
#  Note(start=64.441629, end=64.766708, pitch=52, velocity=49),
#  Note(start=64.766708, end=64.940858, pitch=52, velocity=51),
#  Note(start=64.952468, end=65.603911, pitch=33, velocity=70),
#  Note(start=64.964078, end=65.498137, pitch=83, velocity=57),
#  Note(start=64.975688, end=65.115008, pitch=55, velocity=58),
#  Note(start=64.975688, end=65.196278, pitch=64, velocity=62),
#  Note(start=64.975688, end=65.824500, pitch=60, velocity=66),
#  Note(start=64.987298, end=65.358817, pitch=79, velocity=51),
#  Note(start=64.987298, end=65.615521, pitch=67, velocity=67),
#  Note(start=65.126618, end=65.486527, pitch=48, velocity=41),
#  Note(start=65.196278, end=65.405257, pitch=52, velocity=49),
#  Note(start=65.196278, end=65.405257, pitch=64, velocity=55),
#  Note(start=65.358817, end=65.569081, pitch=78, velocity=54),
#  Note(start=65.393647, end=65.615521, pitch=55, velocity=47),
#  Note(start=65.405257, end=65.557471, pitch=64, velocity=45),
#  Note(start=65.405257, end=65.580691, pitch=52, velocity=47),
#  Note(start=65.615521, end=65.766450, pitch=55, velocity=61),
#  Note(start=65.720010, end=65.940600, pitch=64, velocity=49),
#  Note(start=65.824500, end=66.393389, pitch=60, velocity=52),
#  Note(start=65.836110, end=66.045090, pitch=52, velocity=55),
#  Note(start=65.940600, end=66.114750, pitch=64, velocity=51),
#  Note(start=65.940600, end=66.428219, pitch=76, velocity=60),
#  Note(start=66.056700, end=66.242459, pitch=45, velocity=48),
#  Note(start=66.370169, end=66.590759, pitch=33, velocity=40),
#  Note(start=66.892618, end=67.252527, pitch=79, velocity=44),
#  Note(start=66.892618, end=67.310577, pitch=75, velocity=55),
#  Note(start=66.904228, end=67.055158, pitch=67, velocity=40),
#  Note(start=66.904228, end=67.113208, pitch=70, velocity=49),
#  Note(start=66.904228, end=67.368627, pitch=36, velocity=55),
#  Note(start=66.904228, end=67.531167, pitch=51, velocity=58),
#  Note(start=67.113208, end=67.298967, pitch=70, velocity=39),
#  Note(start=67.368627, end=67.542777, pitch=36, velocity=64),
#  Note(start=67.753040, end=67.973630, pitch=72, velocity=52),
#  Note(start=67.753040, end=68.205829, pitch=53, velocity=50),
#  Note(start=67.764650, end=68.136170, pitch=77, velocity=46),
#  Note(start=67.776260, end=67.950410, pitch=38, velocity=47),
#  Note(start=68.205829, end=68.368369, pitch=50, velocity=52),
#  Note(start=68.205829, end=68.519299, pitch=38, velocity=56),
#  Note(start=68.612179, end=68.832768, pitch=64, velocity=92),
#  Note(start=68.612179, end=68.832768, pitch=67, velocity=48),
#  Note(start=68.832768, end=69.053358, pitch=64, velocity=94),
#  Note(start=68.832768, end=69.053358, pitch=67, velocity=38),
#  Note(start=69.053358, end=69.273947, pitch=64, velocity=87),
#  Note(start=69.053358, end=69.378437, pitch=67, velocity=48),
#  Note(start=69.273947, end=69.482927, pitch=64, velocity=77),
#  Note(start=69.366827, end=69.530651, pitch=79, velocity=38),
#  Note(start=69.378437, end=69.553871, pitch=67, velocity=56),
#  Note(start=69.482927, end=69.658361, pitch=64, velocity=70),
#  Note(start=69.693190, end=70.006660, pitch=67, velocity=56),
#  Note(start=69.902170, end=70.087930, pitch=64, velocity=49),
#  Note(start=70.006660, end=70.180810, pitch=67, velocity=75),
#  Note(start=70.111150, end=70.331739, pitch=69, velocity=93),
#  Note(start=70.122760, end=70.331739, pitch=64, velocity=52),
#  Note(start=70.331739, end=70.552329, pitch=50, velocity=46),
#  Note(start=70.331739, end=70.552329, pitch=69, velocity=65),
#  Note(start=70.436229, end=70.598769, pitch=74, velocity=38),
#  Note(start=70.552329, end=70.761308, pitch=69, velocity=69),
#  Note(start=70.552329, end=70.854188, pitch=50, velocity=46),
#  Note(start=70.656819, end=70.970288, pitch=64, velocity=44),
#  Note(start=70.761308, end=70.981898, pitch=69, velocity=57),
#  Note(start=71.086388, end=71.248927, pitch=74, velocity=43),
#  Note(start=71.086388, end=71.283757, pitch=50, velocity=49),
#  Note(start=71.190878, end=71.376637, pitch=64, velocity=42),
#  Note(start=71.411467, end=71.610121, pitch=50, velocity=37),
#  Note(start=71.411467, end=71.621731, pitch=67, velocity=83),
#  Note(start=71.610121, end=71.772660, pitch=74, velocity=45),
#  Note(start=71.610121, end=71.795880, pitch=50, velocity=53),
#  Note(start=71.610121, end=71.830710, pitch=69, velocity=77),
#  Note(start=71.621731, end=71.795880, pitch=38, velocity=38),
#  Note(start=71.819100, end=71.958420, pitch=67, velocity=54),
#  Note(start=71.819100, end=72.028080, pitch=76, velocity=41),
#  Note(start=71.819100, end=72.109350, pitch=61, velocity=42),
#  Note(start=71.819100, end=72.271889, pitch=71, velocity=79),
#  Note(start=71.842320, end=72.562139, pitch=37, velocity=58),
#  Note(start=71.935200, end=72.144180, pitch=64, velocity=63),
#  Note(start=71.993250, end=72.155790, pitch=25, velocity=44),
#  Note(start=72.144180, end=72.376379, pitch=64, velocity=84),
#  Note(start=72.376379, end=72.689849, pitch=64, velocity=80),
#  Note(start=72.562139, end=72.887218, pitch=37, velocity=57),
#  Note(start=72.608579, end=73.003318, pitch=25, velocity=54),
#  Note(start=72.689849, end=72.898828, pitch=64, velocity=71),
#  Note(start=72.898828, end=73.131028, pitch=64, velocity=88),
#  Note(start=73.131028, end=73.270347, pitch=59, velocity=44),
#  Note(start=73.131028, end=73.270347, pitch=61, velocity=48),
#  Note(start=73.131028, end=73.316787, pitch=64, velocity=63),
#  Note(start=73.131028, end=73.363227, pitch=47, velocity=68),
#  Note(start=73.281957, end=73.432887, pitch=55, velocity=35),
#  Note(start=73.340007, end=73.479327, pitch=62, velocity=50),
#  Note(start=73.340007, end=73.550271, pitch=43, velocity=68),
#  Note(start=73.444497, end=73.643151, pitch=64, velocity=59),
#  Note(start=73.550271, end=73.759250, pitch=48, velocity=49),
#  Note(start=73.550271, end=74.130770, pitch=36, velocity=74),
#  Note(start=73.643151, end=73.863740, pitch=64, velocity=74),
#  Note(start=73.759250, end=74.200429, pitch=48, velocity=48),
#  Note(start=73.863740, end=74.072720, pitch=64, velocity=76),
#  Note(start=74.072720, end=74.409409, pitch=64, velocity=48),
#  Note(start=74.200429, end=74.397799, pitch=48, velocity=70),
#  Note(start=74.200429, end=74.409409, pitch=62, velocity=74),
#  Note(start=74.409409, end=74.629999, pitch=64, velocity=78),
#  Note(start=74.618389, end=75.059568, pitch=66, velocity=67),
#  Note(start=74.629999, end=74.827368, pitch=50, velocity=51),
#  Note(start=74.653219, end=75.013128, pitch=38, velocity=74),
#  Note(start=75.047958, end=75.268547, pitch=50, velocity=76),
#  Note(start=75.059568, end=75.268547, pitch=66, velocity=87),
#  Note(start=75.268547, end=75.465917, pitch=66, velocity=73),
#  Note(start=75.489137, end=75.687790, pitch=64, velocity=79),
#  Note(start=75.489137, end=75.919990, pitch=52, velocity=47),
#  Note(start=75.490421, end=75.931600, pitch=40, velocity=65),
#  Note(start=75.687790, end=75.908380, pitch=64, velocity=66),
#  Note(start=75.908380, end=76.117360, pitch=64, velocity=47),
#  Note(start=75.919990, end=76.117360, pitch=52, velocity=49),
#  Note(start=75.931600, end=76.395999, pitch=40, velocity=71),
#  Note(start=76.117360, end=76.326339, pitch=64, velocity=39),
#  Note(start=76.326339, end=76.523709, pitch=64, velocity=59),
#  Note(start=76.546929, end=76.686249, pitch=59, velocity=39),
#  Note(start=76.558539, end=76.709468, pitch=64, velocity=45),
#  Note(start=76.558539, end=76.755908, pitch=67, velocity=42),
#  Note(start=76.558539, end=76.779128, pitch=47, velocity=74),
#  Note(start=76.674639, end=76.895228, pitch=52, velocity=37),
#  Note(start=76.755908, end=76.964888, pitch=67, velocity=74),
#  Note(start=76.779128, end=76.976498, pitch=40, velocity=58),
#  Note(start=76.964888, end=77.593111, pitch=69, velocity=69),
#  Note(start=76.976498, end=77.627941, pitch=50, velocity=59),
#  Note(start=76.988108, end=78.138780, pitch=38, velocity=67),
#  Note(start=77.627941, end=77.999460, pitch=50, velocity=51),
#  Note(start=78.045900, end=78.231659, pitch=64, velocity=66),
#  Note(start=78.266489, end=78.417419, pitch=55, velocity=51),
#  Note(start=78.266489, end=78.417419, pitch=59, velocity=49),
#  Note(start=78.266489, end=78.452249, pitch=47, velocity=61),
#  Note(start=78.266489, end=78.452249, pitch=62, velocity=57),
#  Note(start=78.266489, end=78.452249, pitch=67, velocity=66),
#  Note(start=78.417419, end=78.591569, pitch=55, velocity=46),
#  Note(start=78.463859, end=78.684449, pitch=69, velocity=80),
#  Note(start=78.475469, end=78.626399, pitch=64, velocity=40),
#  Note(start=78.487079, end=78.661229, pitch=43, velocity=64),
#  Note(start=78.684449, end=79.079188, pitch=78, velocity=51),
#  Note(start=78.684449, end=79.090798, pitch=67, velocity=56),
#  Note(start=78.684449, end=79.114018, pitch=60, velocity=60),
#  Note(start=78.684449, end=79.114018, pitch=71, velocity=75),
#  Note(start=78.696059, end=79.439097, pitch=45, velocity=57),
#  Note(start=78.730888, end=80.334349, pitch=33, velocity=66),
#  Note(start=79.009528, end=79.195288, pitch=64, velocity=37),
#  Note(start=79.114018, end=79.439097, pitch=67, velocity=50),
#  Note(start=79.114018, end=79.533261, pitch=76, velocity=86),
#  Note(start=79.114018, end=79.951220, pitch=60, velocity=51),
#  Note(start=79.439097, end=79.777070, pitch=45, velocity=63),
#  Note(start=79.533261, end=79.800290, pitch=76, velocity=62),
#  Note(start=79.544871, end=79.753850, pitch=64, velocity=60),
#  Note(start=79.753850, end=79.916390, pitch=64, velocity=47),
#  Note(start=79.777070, end=79.997660, pitch=45, velocity=62),
#  Note(start=80.183420, end=80.357569, pitch=64, velocity=47),
#  Note(start=80.287909, end=80.427229, pitch=71, velocity=81),
#  Note(start=80.404009, end=80.972898, pitch=69, velocity=69),
#  Note(start=80.508499, end=80.659429, pitch=64, velocity=59),
#  Note(start=80.636209, end=81.065778, pitch=45, velocity=57),
#  Note(start=80.659429, end=80.949678, pitch=33, velocity=67),
#  Note(start=81.054168, end=81.251537, pitch=67, velocity=65),
#  Note(start=81.065778, end=81.274757, pitch=45, velocity=69),
#  Note(start=81.263147, end=81.473411, pitch=69, velocity=72),
#  Note(start=81.274757, end=81.425687, pitch=45, velocity=48),
#  Note(start=81.461801, end=81.682390, pitch=71, velocity=73),
#  Note(start=81.473411, end=81.635951, pitch=62, velocity=37),
#  Note(start=81.485021, end=81.740440, pitch=47, velocity=55),
#  Note(start=81.543071, end=81.821710, pitch=35, velocity=67),
#  Note(start=81.891370, end=82.065520, pitch=64, velocity=36),
#  Note(start=81.891370, end=82.344159, pitch=71, velocity=91),
#  Note(start=81.902980, end=82.088740, pitch=47, velocity=57),
#  Note(start=81.902980, end=82.123570, pitch=59, velocity=48),
#  Note(start=81.914590, end=82.170010, pitch=62, velocity=40),
#  Note(start=82.111960, end=82.274499, pitch=50, velocity=43),
#  Note(start=82.332549, end=82.866608, pitch=52, velocity=46),
#  Note(start=82.332549, end=82.971098, pitch=79, velocity=84),
#  Note(start=82.344159, end=82.506699, pitch=64, velocity=39),
#  Note(start=82.344159, end=82.936268, pitch=40, velocity=72),
#  Note(start=82.762118, end=82.936268, pitch=67, velocity=56),
#  Note(start=82.866608, end=83.203298, pitch=52, velocity=56),
#  Note(start=82.971098, end=83.226517, pitch=78, velocity=85),
#  Note(start=82.982708, end=83.191688, pitch=64, velocity=57),
#  Note(start=83.191688, end=83.342617, pitch=64, velocity=50),
#  Note(start=83.203298, end=83.423887, pitch=52, velocity=80),
#  Note(start=83.400667, end=83.610931, pitch=74, velocity=78),
#  Note(start=83.412277, end=83.541271, pitch=55, velocity=53),
#  Note(start=83.412277, end=83.552881, pitch=67, velocity=55),
#  Note(start=83.412277, end=83.576101, pitch=59, velocity=51),
#  Note(start=83.412277, end=83.587711, pitch=64, velocity=55),
#  Note(start=83.423887, end=83.634151, pitch=47, velocity=68),
#  Note(start=83.541271, end=83.831520, pitch=55, velocity=72),
#  Note(start=83.610931, end=83.936010, pitch=74, velocity=49),
#  Note(start=83.622541, end=83.785080, pitch=64, velocity=50),
#  Note(start=83.622541, end=83.808300, pitch=40, velocity=58),
#  Note(start=83.831520, end=84.423629, pitch=69, velocity=57),
#  Note(start=83.831520, end=84.481679, pitch=50, velocity=65),
#  Note(start=83.831520, end=84.504899, pitch=38, velocity=65),
#  Note(start=83.936010, end=84.075330, pitch=64, velocity=38),
#  Note(start=84.481679, end=84.969298, pitch=50, velocity=49),
#  Note(start=84.504899, end=85.015738, pitch=38, velocity=74),
#  Note(start=84.899638, end=85.097008, pitch=64, velocity=69),
#  Note(start=85.120228, end=85.329207, pitch=59, velocity=54),
#  Note(start=85.120228, end=85.469811, pitch=55, velocity=48),
#  Note(start=85.131838, end=85.340817, pitch=47, velocity=65),
#  Note(start=85.340817, end=85.539471, pitch=71, velocity=73),
#  Note(start=85.352427, end=85.562691, pitch=43, velocity=68),
#  Note(start=85.597521, end=86.677249, pitch=37, velocity=67),
#  Note(start=85.643961, end=85.864550, pitch=64, velocity=60),
#  Note(start=85.748450, end=86.201239, pitch=79, velocity=89),
#  Note(start=85.864550, end=86.073530, pitch=64, velocity=56),
#  Note(start=85.969040, end=86.398609, pitch=52, velocity=48),
#  Note(start=86.073530, end=86.398609, pitch=64, velocity=46),
#  Note(start=86.398609, end=86.607589, pitch=71, velocity=61),
#  Note(start=86.398609, end=86.642419, pitch=78, velocity=91),
#  Note(start=86.398609, end=86.712078, pitch=52, velocity=53),
#  Note(start=86.410219, end=86.619199, pitch=64, velocity=50),
#  Note(start=86.619199, end=86.839788, pitch=64, velocity=60),
#  Note(start=86.839788, end=86.979108, pitch=59, velocity=44),
#  Note(start=86.839788, end=87.060378, pitch=55, velocity=60),
#  Note(start=86.839788, end=87.060378, pitch=64, velocity=66),
#  Note(start=86.839788, end=87.060378, pitch=74, velocity=75),
#  Note(start=86.839788, end=87.083598, pitch=47, velocity=62),
#  Note(start=87.060378, end=87.211307, pitch=55, velocity=57),
#  Note(start=87.060378, end=87.211307, pitch=64, velocity=44),
#  Note(start=87.071988, end=87.280967, pitch=43, velocity=66),
#  Note(start=87.257747, end=87.468011, pitch=72, velocity=49),
#  Note(start=87.257747, end=87.479621, pitch=48, velocity=49),
#  Note(start=87.257747, end=87.920800, pitch=81, velocity=77),
#  Note(start=87.280967, end=87.804700, pitch=36, velocity=62),
#  Note(start=87.373847, end=87.572501, pitch=64, velocity=42),
#  Note(start=87.468011, end=87.618941, pitch=72, velocity=45),
#  Note(start=87.468011, end=87.781480, pitch=52, velocity=47),
#  Note(start=87.479621, end=87.909190, pitch=48, velocity=52),
#  Note(start=87.572501, end=87.793090, pitch=64, velocity=54),
#  Note(start=87.793090, end=88.083340, pitch=64, velocity=56),
#  Note(start=87.909190, end=88.118170, pitch=48, velocity=72),
#  Note(start=87.909190, end=88.118170, pitch=60, velocity=53),
#  Note(start=88.106560, end=88.338759, pitch=79, velocity=91),
#  Note(start=88.176220, end=88.315539, pitch=52, velocity=56),
#  Note(start=88.327149, end=88.547739, pitch=50, velocity=57),
#  Note(start=88.338759, end=88.512909, pitch=79, velocity=69),
#  Note(start=88.350369, end=88.710278, pitch=38, velocity=60),
#  Note(start=88.536129, end=88.675449, pitch=66, velocity=40),
#  Note(start=88.536129, end=88.768328, pitch=78, velocity=78),
#  Note(start=88.547739, end=88.768328, pitch=50, velocity=62),
#  Note(start=88.652229, end=88.872818, pitch=64, velocity=47),
#  Note(start=88.768328, end=88.919258, pitch=62, velocity=47),
#  Note(start=88.768328, end=88.942478, pitch=67, velocity=53),
#  Note(start=88.768328, end=88.954088, pitch=76, velocity=57),
#  Note(start=88.768328, end=88.988918, pitch=50, velocity=72),
#  Note(start=88.872818, end=89.081798, pitch=64, velocity=38),
#  Note(start=88.977308, end=89.197898, pitch=74, velocity=77),
#  Note(start=89.081798, end=89.244337, pitch=64, velocity=39),
#  Note(start=89.186288, end=90.162810, pitch=76, velocity=65),
#  Note(start=89.197898, end=89.512651, pitch=52, velocity=46),
#  Note(start=89.197898, end=89.605531, pitch=67, velocity=63),
#  Note(start=89.221117, end=89.640361, pitch=40, velocity=63),
#  Note(start=89.512651, end=89.756460, pitch=52, velocity=43),
#  Note(start=89.605531, end=90.104760, pitch=67, velocity=44),
#  Note(start=89.640361, end=89.942220, pitch=40, velocity=73),
#  Note(start=89.942220, end=90.093150, pitch=40, velocity=59),
#  Note(start=90.035100, end=90.267299, pitch=64, velocity=74),
#  Note(start=90.267299, end=90.441449, pitch=64, velocity=52),
#  Note(start=90.267299, end=90.441449, pitch=78, velocity=54),
#  Note(start=90.267299, end=90.464669, pitch=59, velocity=69),
#  Note(start=90.267299, end=90.499499, pitch=47, velocity=68),
#  Note(start=90.476279, end=90.638819, pitch=52, velocity=43),
#  Note(start=90.476279, end=90.696868, pitch=79, velocity=89),
#  Note(start=90.487889, end=90.673649, pitch=40, velocity=56),
#  Note(start=90.685259, end=90.836188, pitch=69, velocity=35),
#  Note(start=90.685259, end=91.347027, pitch=81, velocity=80),
#  Note(start=90.696868, end=91.126438, pitch=66, velocity=43),
#  Note(start=90.696868, end=91.347027, pitch=50, velocity=50),
#  Note(start=90.708478, end=91.358637, pitch=38, velocity=69),
#  Note(start=91.347027, end=91.487631, pitch=50, velocity=50),
#  Note(start=91.358637, end=91.835930, pitch=38, velocity=76),
#  Note(start=91.754660, end=91.940420, pitch=64, velocity=56),
#  Note(start=91.975250, end=92.195839, pitch=79, velocity=85),
#  Note(start=91.986860, end=92.137790, pitch=66, velocity=49),
#  Note(start=91.986860, end=92.184229, pitch=50, velocity=33),
#  Note(start=91.986860, end=92.195839, pitch=62, velocity=47),
#  Note(start=91.986860, end=92.207449, pitch=45, velocity=66),
#  Note(start=92.184229, end=92.335159, pitch=50, velocity=46),
#  Note(start=92.184229, end=92.404819, pitch=81, velocity=85),
#  Note(start=92.195839, end=92.369989, pitch=62, velocity=59),
#  Note(start=92.219059, end=92.404819, pitch=38, velocity=65),
#  Note(start=92.288719, end=92.509309, pitch=64, velocity=45),
#  Note(start=92.393209, end=92.857608, pitch=83, velocity=81),
#  Note(start=92.404819, end=92.544139, pitch=79, velocity=46),
#  Note(start=92.404819, end=92.613799, pitch=48, velocity=47),
#  Note(start=92.439649, end=92.753118, pitch=59, velocity=52),
#  Note(start=92.451259, end=93.474221, pitch=36, velocity=77),
#  Note(start=92.509309, end=92.729898, pitch=64, velocity=64),
#  Note(start=92.544139, end=92.706678, pitch=78, velocity=45),
#  Note(start=92.729898, end=92.938878, pitch=64, velocity=67),
#  Note(start=92.834388, end=93.043368, pitch=67, velocity=38),
#  Note(start=92.834388, end=93.217517, pitch=48, velocity=50),
#  Note(start=92.834388, end=93.252347, pitch=76, velocity=79),
#  Note(start=92.938878, end=93.263957, pitch=64, velocity=56),
#  Note(start=93.043368, end=93.182688, pitch=67, velocity=49),
#  Note(start=93.252347, end=93.439391, pitch=76, velocity=44),
#  Note(start=93.263957, end=93.462611, pitch=64, velocity=51),
#  Note(start=93.462611, end=93.636761, pitch=64, velocity=45),
#  Note(start=93.485831, end=94.043110, pitch=36, velocity=71),
#  Note(start=93.787690, end=94.008280, pitch=64, velocity=56),
#  Note(start=93.903790, end=94.124380, pitch=74, velocity=87),
#  Note(start=94.008280, end=94.217259, pitch=64, velocity=46),
#  Note(start=94.112770, end=94.286919, pitch=57, velocity=49),
#  Note(start=94.112770, end=94.449459, pitch=76, velocity=78),
#  Note(start=94.124380, end=94.356579, pitch=67, velocity=72),
#  Note(start=94.217259, end=94.403019, pitch=64, velocity=59),
#  Note(start=94.333359, end=94.472679, pitch=72, velocity=46),
#  Note(start=94.344969, end=94.704878, pitch=36, velocity=64),
#  Note(start=94.344969, end=94.774538, pitch=48, velocity=58),
#  Note(start=94.542339, end=94.716488, pitch=64, velocity=37),
#  Note(start=94.762928, end=94.913858, pitch=60, velocity=52),
#  Note(start=94.774538, end=94.971908, pitch=55, velocity=60),
#  Note(start=94.774538, end=95.029958, pitch=48, velocity=67),
#  Note(start=94.867418, end=95.099618, pitch=64, velocity=45),
#  Note(start=94.971908, end=95.180888, pitch=76, velocity=63),
#  Note(start=95.029958, end=95.169278, pitch=48, velocity=59),
#  Note(start=95.192498, end=95.391151, pitch=69, velocity=51),
#  Note(start=95.192498, end=95.611741, pitch=50, velocity=64),
#  Note(start=95.192498, end=95.611741, pitch=78, velocity=68),
#  Note(start=95.204107, end=95.367931, pitch=59, velocity=37),
#  Note(start=95.204107, end=95.565301, pitch=38, velocity=63),
#  Note(start=95.611741, end=95.751060, pitch=59, velocity=46),
#  Note(start=95.611741, end=95.936820, pitch=50, velocity=75),
#  Note(start=95.611741, end=96.041310, pitch=78, velocity=68),
#  Note(start=95.623351, end=95.762670, pitch=69, velocity=43),
#  Note(start=95.623351, end=95.797500, pitch=62, velocity=52),
#  Note(start=95.890380, end=96.308339, pitch=38, velocity=44),
#  Note(start=95.936820, end=96.110970, pitch=50, velocity=65)]

# %%
pm_data.instruments[0].notes
# Out:
# [Note(start=0.929545, end=1.102273, pitch=47, velocity=35),
#  Note(start=1.509091, end=1.997727, pitch=28, velocity=63),
#  Note(start=2.904545, end=3.065909, pitch=28, velocity=46),
#  Note(start=3.077273, end=3.775000, pitch=28, velocity=67),
#  Note(start=5.168182, end=5.272727, pitch=40, velocity=49),
#  Note(start=4.959091, end=5.750000, pitch=28, velocity=75),
#  Note(start=8.038636, end=8.165909, pitch=28, velocity=36),
#  Note(start=8.388636, end=8.852273, pitch=28, velocity=66),
#  Note(start=9.909091, end=10.606818, pitch=28, velocity=66),
#  Note(start=11.197727, end=11.302273, pitch=33, velocity=51),
#  Note(start=11.313636, end=11.406818, pitch=45, velocity=38),
#  Note(start=11.302273, end=11.488636, pitch=33, velocity=63),
#  Note(start=11.522727, end=11.638636, pitch=33, velocity=36),
#  Note(start=11.638636, end=11.790909, pitch=33, velocity=54),
#  Note(start=11.836364, end=12.395455, pitch=31, velocity=57),
#  Note(start=13.777273, end=14.311364, pitch=71, velocity=44),
#  Note(start=13.788636, end=14.520455, pitch=79, velocity=54),
#  Note(start=13.777273, end=14.613636, pitch=52, velocity=57),
#  Note(start=13.777273, end=14.625000, pitch=67, velocity=78),
#  Note(start=13.765909, end=14.650000, pitch=64, velocity=93),
#  Note(start=13.765909, end=14.706818, pitch=40, velocity=73),
#  Note(start=14.859091, end=14.963636, pitch=76, velocity=45),
#  Note(start=14.845455, end=14.997727, pitch=71, velocity=40),
#  Note(start=14.845455, end=15.009091, pitch=52, velocity=63),
#  Note(start=14.845455, end=15.043182, pitch=66, velocity=87),
#  Note(start=14.834091, end=15.136364, pitch=40, velocity=54),
#  Note(start=15.043182, end=15.263636, pitch=67, velocity=98),
#  Note(start=15.263636, end=15.497727, pitch=62, velocity=38),
#  Note(start=15.334091, end=15.890909, pitch=78, velocity=48),
#  Note(start=15.263636, end=16.275000, pitch=74, velocity=61),
#  Note(start=15.263636, end=16.311364, pitch=50, velocity=62),
#  Note(start=15.263636, end=16.322727, pitch=66, velocity=75),
#  Note(start=15.263636, end=16.334091, pitch=69, velocity=94),
#  Note(start=16.311364, end=16.415909, pitch=50, velocity=54),
#  Note(start=15.263636, end=16.438636, pitch=38, velocity=85),
#  Note(start=16.577273, end=16.704545, pitch=78, velocity=51),
#  Note(start=16.543182, end=16.740909, pitch=38, velocity=68),
#  Note(start=16.554545, end=16.752273, pitch=50, velocity=70),
#  Note(start=16.543182, end=16.752273, pitch=74, velocity=60),
#  Note(start=16.554545, end=16.786364, pitch=67, velocity=91),
#  Note(start=16.752273, end=16.845455, pitch=50, velocity=51),
#  Note(start=16.740909, end=16.856818, pitch=38, velocity=58),
#  Note(start=16.763636, end=16.995455, pitch=69, velocity=92),
#  Note(start=16.984091, end=17.077273, pitch=52, velocity=44),
#  Note(start=16.984091, end=17.159091, pitch=49, velocity=40),
#  Note(start=16.972727, end=17.368182, pitch=76, velocity=60),
#  Note(start=16.984091, end=17.402273, pitch=64, velocity=72),
#  Note(start=16.984091, end=17.413636, pitch=61, velocity=62),
#  Note(start=16.972727, end=17.425000, pitch=71, velocity=83),
#  Note(start=17.447727, end=17.704545, pitch=49, velocity=50),
#  Note(start=17.843182, end=17.925000, pitch=49, velocity=39),
#  Note(start=16.972727, end=17.936364, pitch=67, velocity=54),
#  Note(start=17.413636, end=17.961364, pitch=61, velocity=47),
#  Note(start=16.972727, end=18.145455, pitch=37, velocity=88),
#  Note(start=17.402273, end=18.261364, pitch=64, velocity=100),
#  Note(start=18.261364, end=18.402273, pitch=49, velocity=45),
#  Note(start=18.261364, end=18.436364, pitch=73, velocity=62),
#  Note(start=18.250000, end=18.447727, pitch=37, velocity=66),
#  Note(start=18.261364, end=18.447727, pitch=61, velocity=65),
#  Note(start=18.250000, end=18.447727, pitch=76, velocity=64),
#  Note(start=18.261364, end=18.470455, pitch=64, velocity=79),
#  Note(start=18.261364, end=18.470455, pitch=67, velocity=71),
#  Note(start=18.447727, end=18.540909, pitch=37, velocity=45),
#  Note(start=18.470455, end=18.715909, pitch=62, velocity=91),
#  Note(start=18.690909, end=18.900000, pitch=64, velocity=102),
#  Note(start=18.900000, end=18.993182, pitch=76, velocity=38),
#  Note(start=18.900000, end=19.306818, pitch=60, velocity=61),
#  Note(start=18.900000, end=19.329545, pitch=64, velocity=93),
#  Note(start=18.900000, end=19.459091, pitch=67, velocity=58),
#  Note(start=18.900000, end=19.459091, pitch=72, velocity=51),
#  Note(start=18.913636, end=19.527273, pitch=48, velocity=68),
#  Note(start=19.329545, end=19.552273, pitch=64, velocity=46),
#  Note(start=19.329545, end=19.563636, pitch=62, velocity=85),
#  Note(start=18.900000, end=19.679545, pitch=36, velocity=78),
#  Note(start=19.552273, end=19.784091, pitch=64, velocity=93),
#  Note(start=19.795455, end=19.863636, pitch=74, velocity=41),
#  Note(start=19.772727, end=20.120455, pitch=69, velocity=50),
#  Note(start=19.772727, end=20.190909, pitch=50, velocity=71),
#  Note(start=19.772727, end=20.190909, pitch=62, velocity=53),
#  Note(start=19.772727, end=20.202273, pitch=66, velocity=100),
#  Note(start=20.190909, end=20.340909, pitch=69, velocity=40),
#  Note(start=20.190909, end=20.377273, pitch=62, velocity=54),
#  Note(start=20.202273, end=20.411364, pitch=66, velocity=102),
#  Note(start=20.190909, end=20.459091, pitch=50, velocity=59),
#  Note(start=19.759091, end=20.538636, pitch=38, velocity=81),
#  Note(start=20.411364, end=20.620455, pitch=66, velocity=92),
#  Note(start=20.643182, end=21.386364, pitch=79, velocity=54),
#  Note(start=20.620455, end=21.397727, pitch=71, velocity=42),
#  Note(start=20.620455, end=21.479545, pitch=67, velocity=77),
#  Note(start=20.620455, end=21.502273, pitch=52, velocity=57),
#  Note(start=20.620455, end=21.525000, pitch=64, velocity=94),
#  Note(start=20.609091, end=21.572727, pitch=40, velocity=71),
#  Note(start=21.711364, end=21.815909, pitch=76, velocity=41),
#  Note(start=21.700000, end=21.852273, pitch=71, velocity=41),
#  Note(start=21.700000, end=21.863636, pitch=52, velocity=61),
#  Note(start=21.700000, end=21.900000, pitch=67, velocity=56),
#  Note(start=21.688636, end=21.979545, pitch=40, velocity=52),
#  Note(start=21.900000, end=22.120455, pitch=67, velocity=96),
#  Note(start=22.120455, end=22.211364, pitch=54, velocity=41),
#  Note(start=22.106818, end=22.363636, pitch=81, velocity=41),
#  Note(start=22.106818, end=22.711364, pitch=78, velocity=41),
#  Note(start=22.120455, end=23.129545, pitch=74, velocity=53),
#  Note(start=22.120455, end=23.152273, pitch=66, velocity=66),
#  Note(start=22.106818, end=23.211364, pitch=69, velocity=90),
#  Note(start=22.106818, end=23.293182, pitch=38, velocity=83),
#  Note(start=22.120455, end=23.420455, pitch=50, velocity=63),
#  Note(start=23.454545, end=23.559091, pitch=74, velocity=46),
#  Note(start=23.443182, end=23.559091, pitch=78, velocity=49),
#  Note(start=23.420455, end=23.581818, pitch=62, velocity=46),
#  Note(start=23.397727, end=23.604545, pitch=38, velocity=68),
#  Note(start=23.420455, end=23.618182, pitch=50, velocity=68),
#  Note(start=23.420455, end=23.629545, pitch=67, velocity=84),
#  Note(start=23.618182, end=23.722727, pitch=50, velocity=60),
#  Note(start=23.604545, end=23.745455, pitch=38, velocity=61),
#  Note(start=23.618182, end=23.838636, pitch=69, velocity=94),
#  Note(start=23.838636, end=23.897727, pitch=64, velocity=37),
#  Note(start=23.838636, end=24.129545, pitch=45, velocity=48),
#  Note(start=23.838636, end=24.234091, pitch=78, velocity=77),
#  Note(start=23.838636, end=24.245455, pitch=60, velocity=75),
#  Note(start=23.838636, end=24.245455, pitch=67, velocity=84),
#  Note(start=23.838636, end=24.245455, pitch=71, velocity=89),
#  Note(start=23.838636, end=24.268182, pitch=52, velocity=65),
#  Note(start=24.256818, end=24.686364, pitch=64, velocity=46),
#  Note(start=24.245455, end=24.686364, pitch=72, velocity=54),
#  Note(start=24.245455, end=24.686364, pitch=76, velocity=102),
#  Note(start=24.245455, end=24.697727, pitch=67, velocity=74),
#  Note(start=24.686364, end=24.813636, pitch=72, velocity=49),
#  Note(start=24.327273, end=25.268182, pitch=45, velocity=59),
#  Note(start=24.686364, end=25.290909, pitch=64, velocity=57),
#  Note(start=24.686364, end=25.313636, pitch=76, velocity=89),
#  Note(start=24.245455, end=25.325000, pitch=60, velocity=87),
#  Note(start=23.850000, end=25.511364, pitch=33, velocity=90),
#  Note(start=25.336364, end=25.568182, pitch=71, velocity=97),
#  Note(start=25.545455, end=25.765909, pitch=69, velocity=103),
#  Note(start=25.777273, end=25.895455, pitch=48, velocity=48),
#  Note(start=25.754545, end=26.104545, pitch=72, velocity=50),
#  Note(start=25.765909, end=26.138636, pitch=64, velocity=55),
#  Note(start=25.765909, end=26.175000, pitch=60, velocity=61),
#  Note(start=25.765909, end=26.175000, pitch=69, velocity=91),
#  Note(start=25.765909, end=26.186364, pitch=67, velocity=48),
#  Note(start=26.209091, end=26.325000, pitch=52, velocity=50),
#  Note(start=26.175000, end=26.336364, pitch=72, velocity=46),
#  Note(start=25.765909, end=26.347727, pitch=45, velocity=49),
#  Note(start=26.186364, end=26.347727, pitch=64, velocity=48),
#  Note(start=26.175000, end=26.370455, pitch=60, velocity=57),
#  Note(start=26.186364, end=26.418182, pitch=67, velocity=92),
#  Note(start=25.743182, end=26.511364, pitch=33, velocity=81),
#  Note(start=26.406818, end=26.661364, pitch=69, velocity=90),
#  Note(start=26.627273, end=26.743182, pitch=50, velocity=51),
#  Note(start=26.615909, end=26.870455, pitch=71, velocity=96),
#  Note(start=26.627273, end=26.952273, pitch=47, velocity=48),
#  Note(start=26.813636, end=27.009091, pitch=78, velocity=56),
#  Note(start=26.615909, end=27.020455, pitch=74, velocity=51),
#  Note(start=26.836364, end=27.034091, pitch=69, velocity=76),
#  Note(start=26.615909, end=27.045455, pitch=62, velocity=65),
#  Note(start=26.627273, end=27.045455, pitch=66, velocity=61),
#  Note(start=27.102273, end=27.393182, pitch=47, velocity=49),
#  Note(start=27.045455, end=27.393182, pitch=66, velocity=43),
#  Note(start=27.045455, end=27.415909, pitch=62, velocity=66),
#  Note(start=26.615909, end=27.497727, pitch=35, velocity=85),
#  Note(start=27.045455, end=27.497727, pitch=71, velocity=101),
#  Note(start=27.486364, end=28.056818, pitch=64, velocity=48),
#  Note(start=27.475000, end=28.113636, pitch=79, velocity=104),
#  Note(start=27.475000, end=28.265909, pitch=67, velocity=62),
#  Note(start=27.486364, end=28.288636, pitch=52, velocity=63),
#  Note(start=28.113636, end=28.288636, pitch=59, velocity=52),
#  Note(start=28.113636, end=28.370455, pitch=78, velocity=96),
#  Note(start=27.463636, end=28.554545, pitch=40, velocity=72),
#  Note(start=28.554545, end=28.670455, pitch=64, velocity=51),
#  Note(start=28.554545, end=28.695455, pitch=71, velocity=33),
#  Note(start=28.554545, end=28.729545, pitch=79, velocity=58),
#  Note(start=28.554545, end=28.752273, pitch=52, velocity=63),
#  Note(start=28.554545, end=28.786364, pitch=67, velocity=68),
#  Note(start=28.554545, end=28.904545, pitch=40, velocity=83),
#  Note(start=28.972727, end=29.218182, pitch=62, velocity=36),
#  Note(start=29.043182, end=29.727273, pitch=78, velocity=48),
#  Note(start=28.554545, end=29.995455, pitch=74, velocity=73),
#  Note(start=28.972727, end=30.031818, pitch=50, velocity=66),
#  Note(start=28.972727, end=30.043182, pitch=69, velocity=96),
#  Note(start=28.984091, end=30.054545, pitch=66, velocity=75),
#  Note(start=28.972727, end=30.147727, pitch=38, velocity=85),
#  Note(start=30.043182, end=30.252273, pitch=69, velocity=92),
#  Note(start=30.031818, end=30.263636, pitch=50, velocity=42),
#  Note(start=30.263636, end=30.450000, pitch=38, velocity=76),
#  Note(start=30.263636, end=30.450000, pitch=62, velocity=55),
#  Note(start=30.263636, end=30.461364, pitch=50, velocity=73),
#  Note(start=30.252273, end=30.461364, pitch=69, velocity=75),
#  Note(start=30.252273, end=30.461364, pitch=74, velocity=77),
#  Note(start=30.252273, end=30.461364, pitch=78, velocity=71),
#  Note(start=30.263636, end=30.495455, pitch=66, velocity=71),
#  Note(start=30.450000, end=30.600000, pitch=38, velocity=74),
#  Note(start=30.472727, end=30.715909, pitch=71, velocity=96),
#  Note(start=30.681818, end=30.854545, pitch=49, velocity=49),
#  Note(start=30.681818, end=30.879545, pitch=73, velocity=59),
#  Note(start=30.693182, end=30.902273, pitch=64, velocity=84),
#  Note(start=30.693182, end=30.902273, pitch=67, velocity=76),
#  Note(start=30.681818, end=30.902273, pitch=76, velocity=63),
#  Note(start=30.890909, end=31.365909, pitch=79, velocity=97),
#  Note(start=31.343182, end=31.470455, pitch=73, velocity=51),
#  Note(start=31.331818, end=31.470455, pitch=76, velocity=49),
#  Note(start=30.693182, end=31.504545, pitch=61, velocity=51),
#  Note(start=30.902273, end=31.518182, pitch=67, velocity=63),
#  Note(start=30.902273, end=31.702273, pitch=64, velocity=74),
#  Note(start=31.552273, end=31.809091, pitch=78, velocity=103),
#  Note(start=30.681818, end=31.843182, pitch=37, velocity=86),
#  Note(start=31.981818, end=32.122727, pitch=61, velocity=58),
#  Note(start=31.970455, end=32.134091, pitch=49, velocity=46),
#  Note(start=31.970455, end=32.145455, pitch=67, velocity=51),
#  Note(start=31.959091, end=32.156818, pitch=37, velocity=74),
#  Note(start=31.981818, end=32.238636, pitch=64, velocity=85),
#  Note(start=31.981818, end=32.238636, pitch=74, velocity=87),
#  Note(start=32.156818, end=32.343182, pitch=37, velocity=74),
#  Note(start=32.609091, end=32.679545, pitch=67, velocity=32),
#  Note(start=32.609091, end=33.202273, pitch=76, velocity=58),
#  Note(start=32.620455, end=33.213636, pitch=64, velocity=63),
#  Note(start=32.609091, end=33.225000, pitch=72, velocity=68),
#  Note(start=32.620455, end=33.247727, pitch=48, velocity=81),
#  Note(start=32.388636, end=33.247727, pitch=81, velocity=96),
#  Note(start=32.609091, end=33.363636, pitch=36, velocity=81),
#  Note(start=33.259091, end=33.479545, pitch=79, velocity=102),
#  Note(start=33.479545, end=33.584091, pitch=62, velocity=30),
#  Note(start=33.479545, end=33.688636, pitch=50, velocity=73),
#  Note(start=33.479545, end=33.688636, pitch=66, velocity=67),
#  Note(start=33.479545, end=33.688636, pitch=74, velocity=74),
#  Note(start=33.479545, end=33.688636, pitch=79, velocity=93),
#  Note(start=33.688636, end=33.829545, pitch=62, velocity=34),
#  Note(start=33.479545, end=33.852273, pitch=69, velocity=59),
#  Note(start=33.688636, end=33.865909, pitch=74, velocity=64),
#  Note(start=33.688636, end=33.900000, pitch=66, velocity=58),
#  Note(start=33.688636, end=33.911364, pitch=78, velocity=92),
#  Note(start=33.688636, end=34.050000, pitch=50, velocity=69),
#  Note(start=33.922727, end=34.050000, pitch=57, velocity=52),
#  Note(start=33.900000, end=34.109091, pitch=66, velocity=79),
#  Note(start=33.888636, end=34.120455, pitch=76, velocity=90),
#  Note(start=33.468182, end=34.225000, pitch=38, velocity=80),
#  Note(start=34.109091, end=34.340909, pitch=74, velocity=94),
#  Note(start=34.318182, end=34.411364, pitch=79, velocity=41),
#  Note(start=34.329545, end=34.829545, pitch=64, velocity=48),
#  Note(start=34.329545, end=35.140909, pitch=71, velocity=51),
#  Note(start=34.329545, end=35.177273, pitch=52, velocity=60),
#  Note(start=34.318182, end=35.188636, pitch=76, velocity=105),
#  Note(start=34.329545, end=35.211364, pitch=67, velocity=86),
#  Note(start=34.318182, end=35.315909, pitch=40, velocity=76),
#  Note(start=35.188636, end=35.409091, pitch=76, velocity=83),
#  Note(start=35.409091, end=35.513636, pitch=64, velocity=40),
#  Note(start=35.409091, end=35.559091, pitch=59, velocity=52),
#  Note(start=35.409091, end=35.559091, pitch=71, velocity=48),
#  Note(start=35.409091, end=35.584091, pitch=52, velocity=63),
#  Note(start=35.397727, end=35.595455, pitch=40, velocity=67),
#  Note(start=35.409091, end=35.618182, pitch=67, velocity=67),
#  Note(start=35.409091, end=35.618182, pitch=78, velocity=88),
#  Note(start=35.595455, end=35.734091, pitch=40, velocity=60),
#  Note(start=35.618182, end=35.840909, pitch=79, velocity=97),
#  Note(start=36.222727, end=36.350000, pitch=78, velocity=40),
#  Note(start=35.852273, end=36.815909, pitch=74, velocity=46),
#  Note(start=35.827273, end=36.838636, pitch=62, velocity=43),
#  Note(start=35.827273, end=36.872727, pitch=66, velocity=75),
#  Note(start=35.827273, end=36.884091, pitch=69, velocity=59),
#  Note(start=35.827273, end=36.943182, pitch=50, velocity=67),
#  Note(start=35.815909, end=37.081818, pitch=81, velocity=84),
#  Note(start=35.815909, end=37.115909, pitch=38, velocity=79),
#  Note(start=37.129545, end=37.268182, pitch=62, velocity=40),
#  Note(start=37.129545, end=37.302273, pitch=74, velocity=61),
#  Note(start=37.115909, end=37.313636, pitch=38, velocity=75),
#  Note(start=37.115909, end=37.313636, pitch=66, velocity=66),
#  Note(start=37.115909, end=37.313636, pitch=69, velocity=74),
#  Note(start=37.129545, end=37.325000, pitch=50, velocity=70),
#  Note(start=37.115909, end=37.350000, pitch=79, velocity=92),
#  Note(start=37.325000, end=37.395455, pitch=50, velocity=47),
#  Note(start=37.313636, end=37.477273, pitch=38, velocity=70),
#  Note(start=37.325000, end=37.559091, pitch=81, velocity=97),
#  Note(start=37.581818, end=37.720455, pitch=48, velocity=49),
#  Note(start=37.545455, end=37.731818, pitch=33, velocity=75),
#  Note(start=37.545455, end=37.943182, pitch=79, velocity=65),
#  Note(start=37.545455, end=37.965909, pitch=60, velocity=72),
#  Note(start=37.545455, end=37.965909, pitch=64, velocity=62),
#  Note(start=37.545455, end=37.965909, pitch=67, velocity=75),
#  Note(start=37.534091, end=37.988636, pitch=83, velocity=97),
#  Note(start=37.559091, end=38.152273, pitch=45, velocity=59),
#  Note(start=37.965909, end=38.395455, pitch=64, velocity=47),
#  Note(start=37.965909, end=38.395455, pitch=76, velocity=103),
#  Note(start=37.965909, end=38.418182, pitch=67, velocity=77),
#  Note(start=37.965909, end=38.534091, pitch=72, velocity=54),
#  Note(start=38.395455, end=38.825000, pitch=76, velocity=93),
#  Note(start=38.406818, end=38.975000, pitch=45, velocity=61),
#  Note(start=38.395455, end=39.000000, pitch=64, velocity=57),
#  Note(start=38.825000, end=39.011364, pitch=76, velocity=75),
#  Note(start=37.965909, end=39.034091, pitch=60, velocity=88),
#  Note(start=37.731818, end=39.209091, pitch=33, velocity=90),
#  Note(start=39.045455, end=39.277273, pitch=74, velocity=95),
#  Note(start=39.254545, end=39.475000, pitch=76, velocity=107),
#  Note(start=39.486364, end=39.650000, pitch=48, velocity=57),
#  Note(start=39.486364, end=39.777273, pitch=45, velocity=48),
#  Note(start=39.475000, end=39.881818, pitch=72, velocity=76),
#  Note(start=39.475000, end=39.881818, pitch=76, velocity=85),
#  Note(start=39.486364, end=39.895455, pitch=67, velocity=83),
#  Note(start=39.486364, end=39.906818, pitch=60, velocity=71),
#  Note(start=39.486364, end=39.906818, pitch=64, velocity=62),
#  Note(start=39.895455, end=40.068182, pitch=67, velocity=57),
#  Note(start=39.906818, end=40.090909, pitch=60, velocity=63),
#  Note(start=39.895455, end=40.127273, pitch=74, velocity=89),
#  Note(start=39.906818, end=40.150000, pitch=64, velocity=74),
#  Note(start=39.463636, end=40.231818, pitch=33, velocity=80),
#  Note(start=40.115909, end=40.347727, pitch=76, velocity=98),
#  Note(start=40.336364, end=40.486364, pitch=50, velocity=65),
#  Note(start=40.336364, end=40.556818, pitch=47, velocity=43),
#  Note(start=40.336364, end=40.718182, pitch=66, velocity=54),
#  Note(start=40.336364, end=40.754545, pitch=62, velocity=67),
#  Note(start=40.325000, end=40.754545, pitch=74, velocity=65),
#  Note(start=40.325000, end=40.754545, pitch=78, velocity=94),
#  Note(start=40.765909, end=40.834091, pitch=50, velocity=49),
#  Note(start=40.754545, end=41.136364, pitch=66, velocity=51),
#  Note(start=40.336364, end=41.136364, pitch=69, velocity=71),
#  Note(start=40.754545, end=41.147727, pitch=62, velocity=69),
#  Note(start=40.754545, end=41.147727, pitch=74, velocity=62),
#  Note(start=41.009091, end=41.159091, pitch=50, velocity=65),
#  Note(start=40.311364, end=41.170455, pitch=35, velocity=90),
#  Note(start=40.754545, end=41.184091, pitch=78, velocity=102),
#  Note(start=41.195455, end=41.275000, pitch=67, velocity=38),
#  Note(start=41.184091, end=41.275000, pitch=79, velocity=41),
#  Note(start=41.206818, end=41.415909, pitch=52, velocity=60),
#  Note(start=41.218182, end=41.472727, pitch=40, velocity=70),
#  Note(start=41.472727, end=41.625000, pitch=40, velocity=36),
#  Note(start=41.625000, end=41.834091, pitch=40, velocity=70),
#  Note(start=41.625000, end=41.881818, pitch=76, velocity=61),
#  Note(start=41.625000, end=41.893182, pitch=52, velocity=59),
#  Note(start=41.625000, end=41.904545, pitch=71, velocity=54),
#  Note(start=41.613636, end=41.904545, pitch=79, velocity=74),
#  Note(start=41.625000, end=41.927273, pitch=64, velocity=56),
#  Note(start=41.625000, end=41.938636, pitch=67, velocity=71),
#  Note(start=42.693182, end=43.122727, pitch=50, velocity=69),
#  Note(start=42.704545, end=43.145455, pitch=38, velocity=83),
#  Note(start=43.145455, end=43.320455, pitch=38, velocity=43),
#  Note(start=43.122727, end=43.331818, pitch=50, velocity=37),
#  Note(start=43.320455, end=43.563636, pitch=38, velocity=67),
#  Note(start=43.331818, end=43.622727, pitch=78, velocity=59),
#  Note(start=43.343182, end=43.645455, pitch=66, velocity=48),
#  Note(start=43.343182, end=43.645455, pitch=69, velocity=59),
#  Note(start=43.331818, end=43.645455, pitch=74, velocity=78),
#  Note(start=43.331818, end=43.656818, pitch=50, velocity=75),
#  Note(start=44.320455, end=44.402273, pitch=28, velocity=40),
#  Note(start=44.402273, end=44.540909, pitch=61, velocity=58),
#  Note(start=44.459091, end=44.540909, pitch=73, velocity=41),
#  Note(start=44.402273, end=44.540909, pitch=91, velocity=55),
#  Note(start=44.402273, end=44.586364, pitch=76, velocity=48),
#  Note(start=44.402273, end=44.611364, pitch=64, velocity=64),
#  Note(start=44.481818, end=44.634091, pitch=49, velocity=58),
#  Note(start=44.402273, end=44.634091, pitch=67, velocity=88),
#  Note(start=44.645455, end=44.795455, pitch=49, velocity=55),
#  Note(start=44.656818, end=44.865909, pitch=37, velocity=73),
#  Note(start=45.052273, end=45.145455, pitch=64, velocity=39),
#  Note(start=45.075000, end=45.225000, pitch=49, velocity=52),
#  Note(start=45.075000, end=45.295455, pitch=37, velocity=75),
#  Note(start=46.120455, end=46.225000, pitch=28, velocity=42),
#  Note(start=46.190909, end=46.352273, pitch=54, velocity=53),
#  Note(start=46.109091, end=46.352273, pitch=82, velocity=65),
#  Note(start=46.284091, end=46.365909, pitch=42, velocity=53),
#  Note(start=46.120455, end=46.365909, pitch=66, velocity=71),
#  Note(start=46.120455, end=46.365909, pitch=73, velocity=81),
#  Note(start=46.120455, end=46.377273, pitch=70, velocity=73),
#  Note(start=46.109091, end=46.422727, pitch=78, velocity=67),
#  Note(start=46.365909, end=46.445455, pitch=54, velocity=45),
#  Note(start=46.352273, end=46.713636, pitch=30, velocity=67),
#  Note(start=46.679545, end=46.770455, pitch=54, velocity=51),
#  Note(start=46.365909, end=46.781818, pitch=42, velocity=73),
#  Note(start=46.781818, end=46.979545, pitch=54, velocity=50),
#  Note(start=46.781818, end=47.050000, pitch=42, velocity=79),
#  Note(start=46.968182, end=47.050000, pitch=70, velocity=32),
#  Note(start=46.979545, end=47.131818, pitch=54, velocity=44),
#  Note(start=46.968182, end=47.143182, pitch=82, velocity=32),
#  Note(start=47.084091, end=47.154545, pitch=73, velocity=45),
#  Note(start=46.968182, end=47.165909, pitch=78, velocity=45),
#  Note(start=47.061364, end=47.177273, pitch=30, velocity=39),
#  Note(start=47.050000, end=47.188636, pitch=42, velocity=59),
#  Note(start=47.177273, end=47.281818, pitch=72, velocity=43),
#  Note(start=47.177273, end=47.281818, pitch=81, velocity=44),
#  Note(start=47.188636, end=47.375000, pitch=53, velocity=49),
#  Note(start=47.259091, end=47.525000, pitch=29, velocity=62),
#  Note(start=47.188636, end=47.606818, pitch=77, velocity=56),
#  Note(start=47.525000, end=47.629545, pitch=53, velocity=53),
#  Note(start=47.225000, end=47.643182, pitch=41, velocity=70),
#  Note(start=47.643182, end=47.806818, pitch=53, velocity=65),
#  Note(start=47.643182, end=47.897727, pitch=41, velocity=72),
#  Note(start=47.897727, end=47.990909, pitch=41, velocity=42),
#  Note(start=48.038636, end=48.131818, pitch=64, velocity=41),
#  Note(start=48.050000, end=48.247727, pitch=52, velocity=55),
#  Note(start=48.084091, end=48.293182, pitch=40, velocity=69),
#  Note(start=48.468182, end=48.688636, pitch=40, velocity=66),
#  Note(start=48.468182, end=48.734091, pitch=76, velocity=58),
#  Note(start=48.479545, end=48.770455, pitch=52, velocity=57),
#  Note(start=48.479545, end=48.770455, pitch=64, velocity=54),
#  Note(start=48.479545, end=48.770455, pitch=71, velocity=54),
#  Note(start=48.468182, end=48.770455, pitch=79, velocity=72),
#  Note(start=48.479545, end=48.804545, pitch=67, velocity=70),
#  Note(start=49.593182, end=50.002273, pitch=38, velocity=80),
#  Note(start=49.559091, end=50.036364, pitch=50, velocity=69),
#  Note(start=50.186364, end=50.443182, pitch=38, velocity=72),
#  Note(start=50.186364, end=50.454545, pitch=66, velocity=47),
#  Note(start=50.186364, end=50.454545, pitch=78, velocity=55),
#  Note(start=50.197727, end=50.465909, pitch=74, velocity=58),
#  Note(start=50.175000, end=50.488636, pitch=81, velocity=67),
#  Note(start=50.186364, end=50.500000, pitch=62, velocity=44),
#  Note(start=50.186364, end=50.500000, pitch=69, velocity=55),
#  Note(start=50.186364, end=50.536364, pitch=50, velocity=66),
#  Note(start=51.138636, end=51.279545, pitch=28, velocity=44),
#  Note(start=51.265909, end=51.500000, pitch=64, velocity=72),
#  Note(start=51.429545, end=51.511364, pitch=45, velocity=78),
#  Note(start=51.265909, end=51.511364, pitch=60, velocity=74),
#  Note(start=51.265909, end=51.522727, pitch=67, velocity=76),
#  Note(start=51.254545, end=51.534091, pitch=83, velocity=73),
#  Note(start=51.511364, end=51.638636, pitch=60, velocity=46),
#  Note(start=51.511364, end=51.686364, pitch=45, velocity=65),
#  Note(start=51.686364, end=51.940909, pitch=45, velocity=48),
#  Note(start=51.545455, end=51.965909, pitch=33, velocity=56),
#  Note(start=51.686364, end=52.022727, pitch=83, velocity=55),
#  Note(start=51.825000, end=52.034091, pitch=72, velocity=45),
#  Note(start=51.279545, end=52.056818, pitch=78, velocity=60),
#  Note(start=51.731818, end=52.068182, pitch=67, velocity=62),
#  Note(start=51.836364, end=52.104545, pitch=60, velocity=44),
#  Note(start=51.940909, end=52.115909, pitch=45, velocity=60),
#  Note(start=51.965909, end=52.127273, pitch=33, velocity=70),
#  Note(start=52.104545, end=52.197727, pitch=79, velocity=41),
#  Note(start=52.104545, end=52.277273, pitch=72, velocity=53),
#  Note(start=52.115909, end=52.336364, pitch=45, velocity=53),
#  Note(start=52.104545, end=52.359091, pitch=83, velocity=46),
#  Note(start=52.336364, end=52.463636, pitch=45, velocity=48),
#  Note(start=52.325000, end=52.500000, pitch=33, velocity=39),
#  Note(start=52.115909, end=52.720455, pitch=60, velocity=66),
#  Note(start=52.104545, end=52.720455, pitch=64, velocity=60),
#  Note(start=52.463636, end=52.731818, pitch=45, velocity=54),
#  Note(start=52.104545, end=52.731818, pitch=76, velocity=84),
#  Note(start=52.777273, end=52.915909, pitch=33, velocity=45),
#  Note(start=53.056818, end=53.125000, pitch=31, velocity=46),
#  Note(start=53.195455, end=53.288636, pitch=48, velocity=35),
#  Note(start=53.345455, end=53.438636, pitch=24, velocity=46),
#  Note(start=53.509091, end=53.579545, pitch=72, velocity=48),
#  Note(start=53.195455, end=53.579545, pitch=76, velocity=45),
#  Note(start=53.195455, end=53.590909, pitch=64, velocity=51),
#  Note(start=53.184091, end=53.613636, pitch=79, velocity=66),
#  Note(start=53.195455, end=53.625000, pitch=60, velocity=49),
#  Note(start=53.195455, end=53.625000, pitch=67, velocity=53),
#  Note(start=53.543182, end=53.636364, pitch=48, velocity=51),
#  Note(start=53.184091, end=53.638636, pitch=36, velocity=68),
#  Note(start=53.638636, end=53.836364, pitch=48, velocity=67),
#  Note(start=53.638636, end=53.859091, pitch=36, velocity=74),
#  Note(start=54.031818, end=54.113636, pitch=66, velocity=39),
#  Note(start=54.031818, end=54.195455, pitch=69, velocity=42),
#  Note(start=54.031818, end=54.206818, pitch=78, velocity=45),
#  Note(start=54.031818, end=54.229545, pitch=50, velocity=43),
#  Note(start=54.079545, end=54.393182, pitch=38, velocity=72),
#  Note(start=54.031818, end=54.450000, pitch=74, velocity=51),
#  Note(start=54.393182, end=54.486364, pitch=50, velocity=46),
#  Note(start=54.393182, end=54.497727, pitch=38, velocity=64),
#  Note(start=54.497727, end=54.659091, pitch=50, velocity=60),
#  Note(start=54.497727, end=54.718182, pitch=38, velocity=83),
#  Note(start=54.718182, end=54.856818, pitch=38, velocity=50),
#  Note(start=54.927273, end=55.020455, pitch=40, velocity=64),
#  Note(start=54.915909, end=55.159091, pitch=52, velocity=49),
#  Note(start=55.020455, end=55.181818, pitch=40, velocity=63),
#  Note(start=55.356818, end=55.461364, pitch=55, velocity=54),
#  Note(start=55.356818, end=55.506818, pitch=52, velocity=50),
#  Note(start=55.356818, end=55.600000, pitch=40, velocity=72),
#  Note(start=55.600000, end=55.845455, pitch=40, velocity=41),
#  Note(start=55.868182, end=55.950000, pitch=52, velocity=48),
#  Note(start=55.972727, end=56.077273, pitch=55, velocity=68),
#  Note(start=56.088636, end=56.193182, pitch=52, velocity=56),
#  Note(start=56.193182, end=56.297727, pitch=52, velocity=65),
#  Note(start=56.297727, end=56.368182, pitch=52, velocity=57),
#  Note(start=56.413636, end=56.738636, pitch=38, velocity=72),
#  Note(start=56.738636, end=56.854545, pitch=38, velocity=60),
#  Note(start=56.402273, end=56.877273, pitch=50, velocity=69),
#  Note(start=57.052273, end=57.122727, pitch=55, velocity=38),
#  Note(start=57.052273, end=57.145455, pitch=66, velocity=44),
#  Note(start=57.040909, end=57.215909, pitch=78, velocity=45),
#  Note(start=57.040909, end=57.261364, pitch=50, velocity=72),
#  Note(start=57.063636, end=57.320455, pitch=38, velocity=66),
#  Note(start=57.261364, end=57.331818, pitch=69, velocity=43),
#  Note(start=57.040909, end=57.343182, pitch=74, velocity=60),
#  Note(start=57.261364, end=57.377273, pitch=50, velocity=56),
#  Note(start=57.365909, end=57.481818, pitch=52, velocity=36),
#  Note(start=57.481818, end=57.597727, pitch=52, velocity=46),
#  Note(start=57.693182, end=57.786364, pitch=55, velocity=71),
#  Note(start=57.597727, end=57.797727, pitch=52, velocity=38),
#  Note(start=57.797727, end=57.902273, pitch=52, velocity=64),
#  Note(start=57.902273, end=58.063636, pitch=52, velocity=44),
#  Note(start=58.040909, end=58.134091, pitch=28, velocity=41),
#  Note(start=58.111364, end=58.202273, pitch=55, velocity=45),
#  Note(start=58.111364, end=58.227273, pitch=52, velocity=46),
#  Note(start=58.111364, end=58.238636, pitch=91, velocity=50),
#  Note(start=58.111364, end=58.250000, pitch=61, velocity=52),
#  Note(start=58.122727, end=58.295455, pitch=64, velocity=50),
#  Note(start=58.111364, end=58.295455, pitch=76, velocity=48),
#  Note(start=58.111364, end=58.343182, pitch=67, velocity=86),
#  Note(start=58.238636, end=58.354545, pitch=49, velocity=44),
#  Note(start=58.227273, end=58.422727, pitch=52, velocity=60),
#  Note(start=58.354545, end=58.493182, pitch=49, velocity=55),
#  Note(start=58.422727, end=58.540909, pitch=52, velocity=63),
#  Note(start=58.365909, end=58.563636, pitch=37, velocity=65),
#  Note(start=58.784091, end=58.922727, pitch=49, velocity=48),
#  Note(start=58.865909, end=58.970455, pitch=52, velocity=56),
#  Note(start=58.784091, end=59.004545, pitch=37, velocity=60),
#  Note(start=59.190909, end=59.306818, pitch=52, velocity=42),
#  Note(start=59.306818, end=59.386364, pitch=52, velocity=54),
#  Note(start=59.411364, end=59.504545, pitch=55, velocity=63),
#  Note(start=59.515909, end=59.620455, pitch=52, velocity=42),
#  Note(start=59.620455, end=59.725000, pitch=52, velocity=59),
#  Note(start=59.725000, end=59.795455, pitch=52, velocity=55),
#  Note(start=59.829545, end=60.050000, pitch=66, velocity=61),
#  Note(start=59.829545, end=60.050000, pitch=73, velocity=69),
#  Note(start=59.818182, end=60.050000, pitch=82, velocity=58),
#  Note(start=59.945455, end=60.061364, pitch=42, velocity=48),
#  Note(start=59.829545, end=60.061364, pitch=70, velocity=63),
#  Note(start=59.818182, end=60.097727, pitch=54, velocity=46),
#  Note(start=59.829545, end=60.109091, pitch=78, velocity=62),
#  Note(start=60.086364, end=60.397727, pitch=30, velocity=62),
#  Note(start=60.061364, end=60.490909, pitch=42, velocity=60),
#  Note(start=60.490909, end=60.595455, pitch=42, velocity=83),
#  Note(start=60.595455, end=60.677273, pitch=42, velocity=72),
#  Note(start=60.490909, end=60.700000, pitch=54, velocity=46),
#  Note(start=60.677273, end=60.759091, pitch=42, velocity=54),
#  Note(start=60.700000, end=60.840909, pitch=54, velocity=43),
#  Note(start=60.688636, end=60.875000, pitch=78, velocity=39),
#  Note(start=60.759091, end=60.897727, pitch=42, velocity=57),
#  Note(start=60.897727, end=60.979545, pitch=81, velocity=40),
#  Note(start=60.897727, end=60.990909, pitch=72, velocity=41),
#  Note(start=60.990909, end=61.200000, pitch=29, velocity=57),
#  Note(start=60.897727, end=61.304545, pitch=77, velocity=48),
#  Note(start=60.909091, end=61.350000, pitch=53, velocity=45),
#  Note(start=60.931818, end=61.361364, pitch=41, velocity=57),
#  Note(start=61.350000, end=61.525000, pitch=53, velocity=57),
#  Note(start=61.361364, end=61.584091, pitch=41, velocity=75),
#  Note(start=61.793182, end=61.875000, pitch=40, velocity=78),
#  Note(start=61.781818, end=61.875000, pitch=52, velocity=46),
#  Note(start=61.875000, end=61.979545, pitch=52, velocity=49),
#  Note(start=61.875000, end=61.990909, pitch=40, velocity=60),
#  Note(start=62.188636, end=62.293182, pitch=52, velocity=49),
#  Note(start=62.188636, end=62.327273, pitch=40, velocity=76),
#  Note(start=62.188636, end=62.338636, pitch=55, velocity=57),
#  Note(start=62.293182, end=62.409091, pitch=52, velocity=51),
#  Note(start=62.327273, end=62.431818, pitch=40, velocity=60),
#  Note(start=62.618182, end=62.790909, pitch=52, velocity=59),
#  Note(start=62.838636, end=62.931818, pitch=55, velocity=64),
#  Note(start=62.943182, end=63.059091, pitch=52, velocity=34),
#  Note(start=63.059091, end=63.220455, pitch=52, velocity=58),
#  Note(start=63.302273, end=63.709091, pitch=38, velocity=67),
#  Note(start=63.268182, end=63.745455, pitch=50, velocity=64),
#  Note(start=63.906818, end=63.977273, pitch=69, velocity=34),
#  Note(start=63.906818, end=64.011364, pitch=66, velocity=43),
#  Note(start=63.895455, end=64.127273, pitch=50, velocity=65),
#  Note(start=63.918182, end=64.152273, pitch=38, velocity=67),
#  Note(start=63.884091, end=64.186364, pitch=81, velocity=45),
#  Note(start=64.104545, end=64.197727, pitch=69, velocity=49),
#  Note(start=64.127273, end=64.209091, pitch=50, velocity=47),
#  Note(start=64.220455, end=64.336364, pitch=52, velocity=36),
#  Note(start=64.336364, end=64.440909, pitch=52, velocity=50),
#  Note(start=64.545455, end=64.650000, pitch=55, velocity=69),
#  Note(start=64.440909, end=64.661364, pitch=52, velocity=41),
#  Note(start=64.661364, end=64.765909, pitch=52, velocity=66),
#  Note(start=64.765909, end=64.870455, pitch=52, velocity=46),
#  Note(start=64.870455, end=64.940909, pitch=52, velocity=57),
#  Note(start=64.975000, end=65.079545, pitch=64, velocity=64),
#  Note(start=64.975000, end=65.115909, pitch=55, velocity=58),
#  Note(start=65.056818, end=65.138636, pitch=45, velocity=42),
#  Note(start=65.079545, end=65.195455, pitch=52, velocity=47),
#  Note(start=65.079545, end=65.195455, pitch=64, velocity=60),
#  Note(start=65.195455, end=65.300000, pitch=52, velocity=49),
#  Note(start=65.195455, end=65.300000, pitch=64, velocity=56),
#  Note(start=64.986364, end=65.359091, pitch=79, velocity=51),
#  Note(start=65.300000, end=65.404545, pitch=52, velocity=49),
#  Note(start=65.300000, end=65.404545, pitch=64, velocity=54),
#  Note(start=65.127273, end=65.486364, pitch=48, velocity=41),
#  Note(start=64.963636, end=65.497727, pitch=83, velocity=57),
#  Note(start=65.404545, end=65.509091, pitch=52, velocity=46),
#  Note(start=65.404545, end=65.556818, pitch=64, velocity=45),
#  Note(start=65.359091, end=65.568182, pitch=78, velocity=54),
#  Note(start=65.509091, end=65.581818, pitch=52, velocity=48),
#  Note(start=64.952273, end=65.604545, pitch=33, velocity=70),
#  Note(start=65.393182, end=65.615909, pitch=55, velocity=47),
#  Note(start=64.986364, end=65.615909, pitch=67, velocity=67),
#  Note(start=65.604545, end=65.709091, pitch=40, velocity=46),
#  Note(start=65.615909, end=65.765909, pitch=55, velocity=61),
#  Note(start=64.975000, end=65.825000, pitch=60, velocity=66),
#  Note(start=65.720455, end=65.825000, pitch=64, velocity=33),
#  Note(start=65.731818, end=65.836364, pitch=52, velocity=49),
#  Note(start=65.825000, end=65.893182, pitch=83, velocity=34),
#  Note(start=65.836364, end=65.940909, pitch=52, velocity=55),
#  Note(start=65.825000, end=65.940909, pitch=64, velocity=63),
#  Note(start=65.825000, end=65.940909, pitch=76, velocity=88),
#  Note(start=65.940909, end=66.045455, pitch=52, velocity=55),
#  Note(start=65.940909, end=66.113636, pitch=64, velocity=51),
#  Note(start=66.045455, end=66.161364, pitch=33, velocity=43),
#  Note(start=66.056818, end=66.243182, pitch=45, velocity=48),
#  Note(start=66.254545, end=66.370455, pitch=55, velocity=65),
#  Note(start=65.825000, end=66.393182, pitch=60, velocity=52),
#  Note(start=66.277273, end=66.404545, pitch=64, velocity=39),
#  Note(start=65.940909, end=66.427273, pitch=76, velocity=60),
#  Note(start=66.370455, end=66.452273, pitch=45, velocity=36),
#  Note(start=66.370455, end=66.486364, pitch=33, velocity=36),
#  Note(start=66.486364, end=66.590909, pitch=33, velocity=45),
#  Note(start=66.579545, end=66.661364, pitch=52, velocity=53),
#  Note(start=66.695455, end=66.765909, pitch=55, velocity=52),
#  Note(start=66.706818, end=66.811364, pitch=31, velocity=39),
#  Note(start=66.800000, end=66.870455, pitch=52, velocity=56),
#  Note(start=66.904545, end=67.020455, pitch=70, velocity=49),
#  Note(start=66.904545, end=67.054545, pitch=67, velocity=40),
#  Note(start=67.020455, end=67.113636, pitch=70, velocity=49),
#  Note(start=66.893182, end=67.252273, pitch=79, velocity=44),
#  Note(start=67.113636, end=67.300000, pitch=70, velocity=39),
#  Note(start=66.893182, end=67.311364, pitch=75, velocity=55),
#  Note(start=66.904545, end=67.368182, pitch=36, velocity=55),
#  Note(start=67.368182, end=67.495455, pitch=48, velocity=43),
#  Note(start=66.904545, end=67.531818, pitch=51, velocity=58),
#  Note(start=67.368182, end=67.543182, pitch=36, velocity=64),
#  Note(start=67.752273, end=67.856818, pitch=81, velocity=41),
#  Note(start=67.777273, end=67.950000, pitch=38, velocity=47),
#  Note(start=67.752273, end=67.972727, pitch=72, velocity=52),
#  Note(start=67.763636, end=68.136364, pitch=77, velocity=46),
#  Note(start=68.102273, end=68.206818, pitch=38, velocity=39),
#  Note(start=67.752273, end=68.206818, pitch=53, velocity=50),
#  Note(start=68.206818, end=68.368182, pitch=50, velocity=52),
#  Note(start=68.206818, end=68.427273, pitch=38, velocity=62),
#  Note(start=68.427273, end=68.518182, pitch=38, velocity=41),
#  Note(start=68.611364, end=68.715909, pitch=67, velocity=45),
#  Note(start=68.611364, end=68.727273, pitch=64, velocity=97),
#  Note(start=68.727273, end=68.831818, pitch=64, velocity=88),
#  Note(start=68.715909, end=68.831818, pitch=67, velocity=51),
#  Note(start=68.831818, end=68.950000, pitch=64, velocity=94),
#  Note(start=68.950000, end=69.052273, pitch=64, velocity=95),
#  Note(start=68.831818, end=69.052273, pitch=67, velocity=38),
#  Note(start=69.052273, end=69.156818, pitch=64, velocity=83),
#  Note(start=69.156818, end=69.275000, pitch=64, velocity=91),
#  Note(start=69.052273, end=69.275000, pitch=67, velocity=44),
#  Note(start=69.275000, end=69.379545, pitch=64, velocity=80),
#  Note(start=69.275000, end=69.379545, pitch=67, velocity=56),
#  Note(start=69.379545, end=69.481818, pitch=64, velocity=74),
#  Note(start=69.379545, end=69.481818, pitch=67, velocity=51),
#  Note(start=69.365909, end=69.529545, pitch=79, velocity=38),
#  Note(start=69.481818, end=69.554545, pitch=67, velocity=61),
#  Note(start=69.481818, end=69.577273, pitch=64, velocity=73),
#  Note(start=69.577273, end=69.659091, pitch=64, velocity=65),
#  Note(start=69.693182, end=69.890909, pitch=67, velocity=31),
#  Note(start=69.786364, end=69.902273, pitch=64, velocity=34),
#  Note(start=69.902273, end=70.006818, pitch=64, velocity=47),
#  Note(start=69.890909, end=70.006818, pitch=67, velocity=97),
#  Note(start=70.006818, end=70.088636, pitch=64, velocity=53),
#  Note(start=70.006818, end=70.111364, pitch=67, velocity=87),
#  Note(start=70.111364, end=70.181818, pitch=67, velocity=56),
#  Note(start=70.122727, end=70.215909, pitch=64, velocity=38),
#  Note(start=70.215909, end=70.331818, pitch=64, velocity=63),
#  Note(start=70.111364, end=70.331818, pitch=69, velocity=93),
#  Note(start=70.331818, end=70.436364, pitch=50, velocity=35),
#  Note(start=70.331818, end=70.436364, pitch=69, velocity=72),
#  Note(start=70.320455, end=70.436364, pitch=74, velocity=42),
#  Note(start=70.436364, end=70.552273, pitch=50, velocity=56),
#  Note(start=70.436364, end=70.552273, pitch=69, velocity=59),
#  Note(start=70.436364, end=70.597727, pitch=74, velocity=38),
#  Note(start=70.552273, end=70.656818, pitch=64, velocity=37),
#  Note(start=70.552273, end=70.761364, pitch=69, velocity=69),
#  Note(start=70.552273, end=70.772727, pitch=50, velocity=42),
#  Note(start=70.772727, end=70.854545, pitch=50, velocity=55),
#  Note(start=70.656818, end=70.865909, pitch=64, velocity=36),
#  Note(start=70.865909, end=70.970455, pitch=64, velocity=59),
#  Note(start=70.761364, end=70.981818, pitch=69, velocity=57),
#  Note(start=70.993182, end=71.075000, pitch=74, velocity=36),
#  Note(start=70.981818, end=71.086364, pitch=50, velocity=34),
#  Note(start=71.086364, end=71.202273, pitch=50, velocity=47),
#  Note(start=71.086364, end=71.250000, pitch=74, velocity=43),
#  Note(start=71.202273, end=71.284091, pitch=50, velocity=52),
#  Note(start=71.190909, end=71.295455, pitch=64, velocity=31),
#  Note(start=71.295455, end=71.377273, pitch=64, velocity=57),
#  Note(start=71.411364, end=71.518182, pitch=67, velocity=94),
#  Note(start=71.515909, end=71.609091, pitch=50, velocity=41),
#  Note(start=71.515909, end=71.609091, pitch=69, velocity=21),
#  Note(start=71.515909, end=71.609091, pitch=74, velocity=40),
#  Note(start=71.518182, end=71.622727, pitch=67, velocity=71),
#  Note(start=71.609091, end=71.713636, pitch=50, velocity=53),
#  Note(start=71.609091, end=71.713636, pitch=69, velocity=82),
#  Note(start=71.622727, end=71.727273, pitch=38, velocity=34),
#  Note(start=71.609091, end=71.772727, pitch=74, velocity=45),
#  Note(start=71.727273, end=71.795455, pitch=38, velocity=44),
#  Note(start=71.713636, end=71.795455, pitch=50, velocity=52),
#  Note(start=71.713636, end=71.831818, pitch=69, velocity=72),
#  Note(start=71.831818, end=71.934091, pitch=64, velocity=41),
#  Note(start=71.818182, end=71.959091, pitch=67, velocity=54),
#  Note(start=71.818182, end=72.027273, pitch=76, velocity=41),
#  Note(start=71.934091, end=72.038636, pitch=64, velocity=60),
#  Note(start=71.818182, end=72.109091, pitch=61, velocity=42),
#  Note(start=72.038636, end=72.143182, pitch=64, velocity=65),
#  Note(start=71.993182, end=72.156818, pitch=25, velocity=44),
#  Note(start=72.143182, end=72.261364, pitch=64, velocity=71),
#  Note(start=71.818182, end=72.272727, pitch=71, velocity=79),
#  Note(start=72.261364, end=72.377273, pitch=64, velocity=97),
#  Note(start=71.843182, end=72.493182, pitch=37, velocity=59),
#  Note(start=72.493182, end=72.561364, pitch=37, velocity=49),
#  Note(start=72.377273, end=72.586364, pitch=64, velocity=82),
#  Note(start=72.586364, end=72.690909, pitch=64, velocity=76),
#  Note(start=72.690909, end=72.795455, pitch=64, velocity=71),
#  Note(start=72.561364, end=72.886364, pitch=37, velocity=57),
#  Note(start=72.795455, end=72.897727, pitch=64, velocity=71),
#  Note(start=72.609091, end=73.002273, pitch=25, velocity=54),
#  Note(start=72.897727, end=73.015909, pitch=64, velocity=92),
#  Note(start=73.015909, end=73.131818, pitch=64, velocity=83),
#  Note(start=73.131818, end=73.225000, pitch=64, velocity=68),
#  Note(start=73.131818, end=73.270455, pitch=59, velocity=44),
#  Note(start=73.131818, end=73.270455, pitch=61, velocity=48),
#  Note(start=73.225000, end=73.315909, pitch=64, velocity=58),
#  Note(start=73.131818, end=73.363636, pitch=47, velocity=68),
#  Note(start=73.340909, end=73.431818, pitch=55, velocity=38),
#  Note(start=73.340909, end=73.479545, pitch=62, velocity=50),
#  Note(start=73.445455, end=73.538636, pitch=64, velocity=37),
#  Note(start=73.340909, end=73.550000, pitch=43, velocity=68),
#  Note(start=73.538636, end=73.643182, pitch=64, velocity=82),
#  Note(start=73.550000, end=73.759091, pitch=48, velocity=49),
#  Note(start=73.643182, end=73.759091, pitch=64, velocity=72),
#  Note(start=73.759091, end=73.863636, pitch=64, velocity=78),
#  Note(start=73.863636, end=73.968182, pitch=64, velocity=77),
#  Note(start=73.968182, end=74.072727, pitch=64, velocity=74),
#  Note(start=73.550000, end=74.131818, pitch=36, velocity=74),
#  Note(start=73.759091, end=74.200000, pitch=48, velocity=48),
#  Note(start=74.072727, end=74.293182, pitch=64, velocity=46),
#  Note(start=74.200000, end=74.397727, pitch=48, velocity=70),
#  Note(start=74.200000, end=74.409091, pitch=62, velocity=74),
#  Note(start=74.293182, end=74.409091, pitch=64, velocity=53),
#  Note(start=74.479545, end=74.595455, pitch=36, velocity=57),
#  Note(start=74.409091, end=74.629545, pitch=64, velocity=78),
#  Note(start=74.629545, end=74.827273, pitch=50, velocity=51),
#  Note(start=74.652273, end=75.013636, pitch=38, velocity=74),
#  Note(start=74.618182, end=75.059091, pitch=66, velocity=67),
#  Note(start=75.047727, end=75.268182, pitch=50, velocity=76),
#  Note(start=75.059091, end=75.268182, pitch=66, velocity=87),
#  Note(start=75.350000, end=75.431818, pitch=38, velocity=54),
#  Note(start=75.268182, end=75.465909, pitch=66, velocity=73),
#  Note(start=75.361364, end=75.488636, pitch=64, velocity=46),
#  Note(start=75.488636, end=75.584091, pitch=64, velocity=85),
#  Note(start=75.584091, end=75.688636, pitch=64, velocity=74),
#  Note(start=75.688636, end=75.793182, pitch=64, velocity=69),
#  Note(start=75.488636, end=75.804545, pitch=52, velocity=46),
#  Note(start=75.793182, end=75.909091, pitch=64, velocity=63),
#  Note(start=75.804545, end=75.920455, pitch=52, velocity=50),
#  Note(start=75.490909, end=75.931818, pitch=40, velocity=65),
#  Note(start=75.909091, end=76.002273, pitch=64, velocity=51),
#  Note(start=75.920455, end=76.118182, pitch=52, velocity=49),
#  Note(start=76.002273, end=76.118182, pitch=64, velocity=44),
#  Note(start=76.118182, end=76.222727, pitch=64, velocity=41),
#  Note(start=76.222727, end=76.327273, pitch=64, velocity=37),
#  Note(start=75.931818, end=76.395455, pitch=40, velocity=71),
#  Note(start=76.327273, end=76.443182, pitch=64, velocity=55),
#  Note(start=76.443182, end=76.522727, pitch=64, velocity=63),
#  Note(start=76.547727, end=76.686364, pitch=59, velocity=39),
#  Note(start=76.559091, end=76.709091, pitch=64, velocity=45),
#  Note(start=76.559091, end=76.756818, pitch=67, velocity=42),
#  Note(start=76.559091, end=76.779545, pitch=47, velocity=74),
#  Note(start=76.768182, end=76.895455, pitch=52, velocity=40),
#  Note(start=76.756818, end=76.965909, pitch=67, velocity=74),
#  Note(start=76.779545, end=76.977273, pitch=40, velocity=58),
#  Note(start=76.977273, end=77.056818, pitch=66, velocity=43),
#  Note(start=76.965909, end=77.056818, pitch=81, velocity=38),
#  Note(start=76.965909, end=77.593182, pitch=69, velocity=69),
#  Note(start=76.977273, end=77.627273, pitch=50, velocity=59),
#  Note(start=77.627273, end=78.000000, pitch=50, velocity=51),
#  Note(start=77.929545, end=78.045455, pitch=64, velocity=35),
#  Note(start=76.988636, end=78.138636, pitch=38, velocity=67),
#  Note(start=78.045455, end=78.150000, pitch=64, velocity=66),
#  Note(start=78.150000, end=78.231818, pitch=64, velocity=65),
#  Note(start=78.265909, end=78.418182, pitch=55, velocity=51),
#  Note(start=78.265909, end=78.418182, pitch=59, velocity=49),
#  Note(start=78.265909, end=78.452273, pitch=47, velocity=61),
#  Note(start=78.265909, end=78.452273, pitch=62, velocity=57),
#  Note(start=78.265909, end=78.452273, pitch=67, velocity=66),
#  Note(start=78.418182, end=78.486364, pitch=55, velocity=50),
#  Note(start=78.486364, end=78.590909, pitch=55, velocity=44),
#  Note(start=78.475000, end=78.627273, pitch=64, velocity=40),
#  Note(start=78.486364, end=78.661364, pitch=43, velocity=64),
#  Note(start=78.463636, end=78.684091, pitch=69, velocity=80),
#  Note(start=78.684091, end=79.079545, pitch=78, velocity=51),
#  Note(start=78.684091, end=79.090909, pitch=67, velocity=56),
#  Note(start=78.684091, end=79.113636, pitch=60, velocity=60),
#  Note(start=78.684091, end=79.113636, pitch=71, velocity=75),
#  Note(start=79.009091, end=79.125000, pitch=64, velocity=31),
#  Note(start=79.125000, end=79.195455, pitch=64, velocity=47),
#  Note(start=79.113636, end=79.334091, pitch=67, velocity=45),
#  Note(start=78.695455, end=79.370455, pitch=45, velocity=57),
#  Note(start=79.370455, end=79.438636, pitch=45, velocity=62),
#  Note(start=79.334091, end=79.438636, pitch=67, velocity=60),
#  Note(start=79.113636, end=79.534091, pitch=76, velocity=86),
#  Note(start=79.438636, end=79.545455, pitch=64, velocity=49),
#  Note(start=79.545455, end=79.650000, pitch=64, velocity=57),
#  Note(start=79.650000, end=79.754545, pitch=64, velocity=62),
#  Note(start=79.438636, end=79.777273, pitch=45, velocity=63),
#  Note(start=79.534091, end=79.800000, pitch=76, velocity=62),
#  Note(start=79.754545, end=79.915909, pitch=64, velocity=47),
#  Note(start=79.113636, end=79.952273, pitch=60, velocity=51),
#  Note(start=79.777273, end=79.997727, pitch=45, velocity=62),
#  Note(start=79.963636, end=80.031818, pitch=67, velocity=47),
#  Note(start=80.184091, end=80.288636, pitch=64, velocity=41),
#  Note(start=80.184091, end=80.288636, pitch=71, velocity=101),
#  Note(start=80.184091, end=80.311364, pitch=52, velocity=49),
#  Note(start=78.731818, end=80.334091, pitch=33, velocity=66),
#  Note(start=80.288636, end=80.356818, pitch=64, velocity=57),
#  Note(start=80.288636, end=80.427273, pitch=71, velocity=81),
#  Note(start=80.520455, end=80.636364, pitch=45, velocity=34),
#  Note(start=80.509091, end=80.659091, pitch=64, velocity=59),
#  Note(start=80.659091, end=80.950000, pitch=33, velocity=67),
#  Note(start=80.404545, end=80.972727, pitch=69, velocity=69),
#  Note(start=80.636364, end=81.065909, pitch=45, velocity=57),
#  Note(start=81.065909, end=81.193182, pitch=57, velocity=52),
#  Note(start=81.088636, end=81.193182, pitch=60, velocity=46),
#  Note(start=81.054545, end=81.252273, pitch=67, velocity=65),
#  Note(start=81.065909, end=81.275000, pitch=45, velocity=69),
#  Note(start=81.275000, end=81.425000, pitch=45, velocity=48),
#  Note(start=81.263636, end=81.472727, pitch=69, velocity=72),
#  Note(start=81.472727, end=81.636364, pitch=62, velocity=37),
#  Note(start=81.461364, end=81.681818, pitch=71, velocity=73),
#  Note(start=81.484091, end=81.740909, pitch=47, velocity=55),
#  Note(start=81.543182, end=81.822727, pitch=35, velocity=67),
#  Note(start=81.890909, end=82.065909, pitch=64, velocity=36),
#  Note(start=81.902273, end=82.088636, pitch=47, velocity=57),
#  Note(start=81.902273, end=82.122727, pitch=59, velocity=48),
#  Note(start=81.913636, end=82.170455, pitch=62, velocity=40),
#  Note(start=82.111364, end=82.193182, pitch=67, velocity=49),
#  Note(start=81.890909, end=82.227273, pitch=71, velocity=98),
#  Note(start=82.111364, end=82.275000, pitch=50, velocity=43),
#  Note(start=82.227273, end=82.331818, pitch=52, velocity=54),
#  Note(start=82.227273, end=82.343182, pitch=71, velocity=70),
#  Note(start=82.343182, end=82.436364, pitch=64, velocity=36),
#  Note(start=82.436364, end=82.506818, pitch=64, velocity=44),
#  Note(start=82.668182, end=82.750000, pitch=67, velocity=50),
#  Note(start=82.331818, end=82.865909, pitch=52, velocity=46),
#  Note(start=82.343182, end=82.936364, pitch=40, velocity=72),
#  Note(start=82.761364, end=82.936364, pitch=67, velocity=56),
#  Note(start=82.331818, end=82.970455, pitch=79, velocity=84),
#  Note(start=82.865909, end=82.981818, pitch=64, velocity=55),
#  Note(start=82.993182, end=83.075000, pitch=59, velocity=48),
#  Note(start=82.865909, end=83.086364, pitch=52, velocity=60),
#  Note(start=82.981818, end=83.086364, pitch=64, velocity=59),
#  Note(start=83.075000, end=83.156818, pitch=50, velocity=48),
#  Note(start=83.086364, end=83.190909, pitch=64, velocity=55),
#  Note(start=83.086364, end=83.202273, pitch=52, velocity=49),
#  Note(start=82.970455, end=83.227273, pitch=78, velocity=85),
#  Note(start=83.190909, end=83.343182, pitch=64, velocity=50),
#  Note(start=83.202273, end=83.425000, pitch=52, velocity=80),
#  Note(start=83.411364, end=83.495455, pitch=64, velocity=54),
#  Note(start=83.411364, end=83.540909, pitch=55, velocity=53),
#  Note(start=83.411364, end=83.552273, pitch=67, velocity=55),
#  Note(start=83.411364, end=83.575000, pitch=59, velocity=51),
#  Note(start=83.495455, end=83.588636, pitch=64, velocity=57),
#  Note(start=83.400000, end=83.611364, pitch=74, velocity=78),
#  Note(start=83.425000, end=83.634091, pitch=47, velocity=68),
#  Note(start=83.622727, end=83.738636, pitch=52, velocity=41),
#  Note(start=83.622727, end=83.784091, pitch=64, velocity=50),
#  Note(start=83.622727, end=83.809091, pitch=40, velocity=58),
#  Note(start=83.540909, end=83.831818, pitch=55, velocity=72),
#  Note(start=83.611364, end=83.936364, pitch=74, velocity=49),
#  Note(start=83.936364, end=84.075000, pitch=64, velocity=38),
#  Note(start=83.831818, end=84.365909, pitch=50, velocity=64),
#  Note(start=84.261364, end=84.388636, pitch=64, velocity=29),
#  Note(start=83.831818, end=84.422727, pitch=69, velocity=57),
#  Note(start=84.365909, end=84.481818, pitch=50, velocity=70),
#  Note(start=83.831818, end=84.504545, pitch=38, velocity=65),
#  Note(start=84.795455, end=84.900000, pitch=64, velocity=35),
#  Note(start=84.481818, end=84.968182, pitch=50, velocity=49),
#  Note(start=84.900000, end=85.004545, pitch=64, velocity=70),
#  Note(start=84.504545, end=85.015909, pitch=38, velocity=74),
#  Note(start=84.922727, end=85.050000, pitch=69, velocity=46),
#  Note(start=85.004545, end=85.097727, pitch=64, velocity=69),
#  Note(start=85.120455, end=85.259091, pitch=55, velocity=61),
#  Note(start=85.120455, end=85.329545, pitch=59, velocity=54),
#  Note(start=85.131818, end=85.340909, pitch=47, velocity=65),
#  Note(start=85.352273, end=85.470455, pitch=55, velocity=46),
#  Note(start=85.340909, end=85.538636, pitch=71, velocity=73),
#  Note(start=85.352273, end=85.563636, pitch=43, velocity=68),
#  Note(start=85.538636, end=85.643182, pitch=64, velocity=41),
#  Note(start=85.563636, end=85.690909, pitch=49, velocity=39),
#  Note(start=85.643182, end=85.759091, pitch=64, velocity=57),
#  Note(start=85.759091, end=85.863636, pitch=64, velocity=63),
#  Note(start=85.759091, end=85.888636, pitch=67, velocity=41),
#  Note(start=85.759091, end=85.888636, pitch=73, velocity=39),
#  Note(start=85.863636, end=85.968182, pitch=64, velocity=65),
#  Note(start=85.968182, end=86.072727, pitch=64, velocity=46),
#  Note(start=85.747727, end=86.202273, pitch=79, velocity=89),
#  Note(start=86.177273, end=86.270455, pitch=67, velocity=62),
#  Note(start=86.072727, end=86.293182, pitch=64, velocity=37),
#  Note(start=85.968182, end=86.397727, pitch=52, velocity=48),
#  Note(start=86.293182, end=86.397727, pitch=64, velocity=66),
#  Note(start=86.409091, end=86.502273, pitch=64, velocity=42),
#  Note(start=86.397727, end=86.502273, pitch=71, velocity=65),
#  Note(start=86.502273, end=86.606818, pitch=71, velocity=56),
#  Note(start=86.502273, end=86.618182, pitch=64, velocity=56),
#  Note(start=86.397727, end=86.643182, pitch=78, velocity=91),
#  Note(start=85.597727, end=86.677273, pitch=37, velocity=67),
#  Note(start=86.397727, end=86.711364, pitch=52, velocity=53),
#  Note(start=86.618182, end=86.722727, pitch=64, velocity=61),
#  Note(start=86.722727, end=86.840909, pitch=64, velocity=59),
#  Note(start=86.840909, end=86.943182, pitch=64, velocity=70),
#  Note(start=86.840909, end=86.979545, pitch=59, velocity=44),
#  Note(start=86.840909, end=86.990909, pitch=55, velocity=56),
#  Note(start=86.990909, end=87.061364, pitch=55, velocity=66),
#  Note(start=86.943182, end=87.061364, pitch=64, velocity=62),
#  Note(start=86.840909, end=87.061364, pitch=74, velocity=75),
#  Note(start=86.840909, end=87.084091, pitch=47, velocity=62),
#  Note(start=87.061364, end=87.211364, pitch=55, velocity=57),
#  Note(start=87.061364, end=87.211364, pitch=64, velocity=44),
#  Note(start=87.072727, end=87.281818, pitch=43, velocity=66),
#  Note(start=87.372727, end=87.456818, pitch=52, velocity=39),
#  Note(start=87.372727, end=87.468182, pitch=64, velocity=28),
#  Note(start=87.256818, end=87.468182, pitch=72, velocity=49),
#  Note(start=87.256818, end=87.479545, pitch=48, velocity=49),
#  Note(start=87.468182, end=87.572727, pitch=64, velocity=55),
#  Note(start=87.468182, end=87.618182, pitch=72, velocity=45),
#  Note(start=87.572727, end=87.677273, pitch=64, velocity=52),
#  Note(start=87.468182, end=87.781818, pitch=52, velocity=47),
#  Note(start=87.677273, end=87.793182, pitch=64, velocity=56),
#  Note(start=87.281818, end=87.804545, pitch=36, velocity=62),
#  Note(start=87.759091, end=87.863636, pitch=72, velocity=52),
#  Note(start=87.479545, end=87.909091, pitch=48, velocity=52),
#  Note(start=87.256818, end=87.920455, pitch=81, velocity=77),
#  Note(start=87.793182, end=88.002273, pitch=64, velocity=53),
#  Note(start=88.002273, end=88.084091, pitch=64, velocity=64),
#  Note(start=87.909091, end=88.118182, pitch=48, velocity=72),
#  Note(start=87.909091, end=88.118182, pitch=60, velocity=53),
#  Note(start=88.211364, end=88.304545, pitch=36, velocity=50),
#  Note(start=88.222727, end=88.327273, pitch=52, velocity=57),
#  Note(start=88.106818, end=88.338636, pitch=79, velocity=91),
#  Note(start=88.338636, end=88.513636, pitch=79, velocity=69),
#  Note(start=88.327273, end=88.547727, pitch=50, velocity=57),
#  Note(start=88.536364, end=88.675000, pitch=66, velocity=40),
#  Note(start=88.350000, end=88.711364, pitch=38, velocity=60),
#  Note(start=88.547727, end=88.768182, pitch=50, velocity=62),
#  Note(start=88.652273, end=88.768182, pitch=64, velocity=31),
#  Note(start=88.536364, end=88.768182, pitch=78, velocity=78),
#  Note(start=88.768182, end=88.872727, pitch=64, velocity=65),
#  Note(start=88.768182, end=88.918182, pitch=62, velocity=47),
#  Note(start=88.768182, end=88.943182, pitch=67, velocity=53),
#  Note(start=88.768182, end=88.954545, pitch=76, velocity=57),
#  Note(start=88.768182, end=88.988636, pitch=50, velocity=72),
#  Note(start=88.872727, end=89.081818, pitch=64, velocity=38),
#  Note(start=89.047727, end=89.175000, pitch=38, velocity=56),
#  Note(start=88.977273, end=89.197727, pitch=74, velocity=77),
#  Note(start=89.081818, end=89.245455, pitch=64, velocity=39),
#  Note(start=89.197727, end=89.513636, pitch=52, velocity=46),
#  Note(start=89.197727, end=89.604545, pitch=67, velocity=63),
#  Note(start=89.513636, end=89.618182, pitch=52, velocity=47),
#  Note(start=89.220455, end=89.640909, pitch=40, velocity=63),
#  Note(start=89.629545, end=89.756818, pitch=52, velocity=40),
#  Note(start=89.640909, end=89.943182, pitch=40, velocity=73),
#  Note(start=89.929545, end=90.034091, pitch=64, velocity=30),
#  Note(start=89.943182, end=90.093182, pitch=40, velocity=59),
#  Note(start=89.604545, end=90.104545, pitch=67, velocity=44),
#  Note(start=90.034091, end=90.152273, pitch=64, velocity=79),
#  Note(start=89.186364, end=90.163636, pitch=76, velocity=65),
#  Note(start=90.152273, end=90.268182, pitch=64, velocity=69),
#  Note(start=90.268182, end=90.372727, pitch=64, velocity=51),
#  Note(start=90.268182, end=90.384091, pitch=69, velocity=32),
#  Note(start=90.372727, end=90.440909, pitch=64, velocity=54),
#  Note(start=90.268182, end=90.440909, pitch=78, velocity=54),
#  Note(start=90.268182, end=90.463636, pitch=59, velocity=69),
#  Note(start=90.268182, end=90.500000, pitch=47, velocity=68),
#  Note(start=90.522727, end=90.615909, pitch=55, velocity=45),
#  Note(start=90.477273, end=90.638636, pitch=52, velocity=43),
#  Note(start=90.488636, end=90.672727, pitch=40, velocity=56),
#  Note(start=90.477273, end=90.697727, pitch=79, velocity=89),
#  Note(start=90.686364, end=90.765909, pitch=74, velocity=33),
#  Note(start=90.686364, end=90.836364, pitch=69, velocity=35),
#  Note(start=90.697727, end=91.127273, pitch=66, velocity=43),
#  Note(start=90.697727, end=91.347727, pitch=50, velocity=50),
#  Note(start=90.686364, end=91.347727, pitch=81, velocity=80),
#  Note(start=90.709091, end=91.359091, pitch=38, velocity=69),
#  Note(start=91.347727, end=91.488636, pitch=50, velocity=50),
#  Note(start=91.638636, end=91.754545, pitch=64, velocity=32),
#  Note(start=91.359091, end=91.836364, pitch=38, velocity=76),
#  Note(start=91.754545, end=91.870455, pitch=64, velocity=55),
#  Note(start=91.870455, end=91.940909, pitch=64, velocity=57),
#  Note(start=91.986364, end=92.079545, pitch=74, velocity=37),
#  Note(start=91.986364, end=92.090909, pitch=55, velocity=41),
#  Note(start=91.986364, end=92.113636, pitch=69, velocity=32),
#  Note(start=91.986364, end=92.138636, pitch=66, velocity=49),
#  Note(start=92.079545, end=92.184091, pitch=50, velocity=44),
#  Note(start=91.986364, end=92.195455, pitch=62, velocity=47),
#  Note(start=91.975000, end=92.195455, pitch=79, velocity=85),
#  Note(start=91.986364, end=92.206818, pitch=45, velocity=66),
#  Note(start=92.184091, end=92.334091, pitch=50, velocity=46),
#  Note(start=92.195455, end=92.370455, pitch=62, velocity=59),
#  Note(start=92.218182, end=92.404545, pitch=38, velocity=65),
#  Note(start=92.184091, end=92.404545, pitch=81, velocity=85),
#  Note(start=92.404545, end=92.475000, pitch=55, velocity=36),
#  Note(start=92.404545, end=92.486364, pitch=67, velocity=43),
#  Note(start=92.404545, end=92.509091, pitch=64, velocity=63),
#  Note(start=92.404545, end=92.543182, pitch=79, velocity=46),
#  Note(start=92.404545, end=92.613636, pitch=48, velocity=47),
#  Note(start=92.509091, end=92.613636, pitch=64, velocity=63),
#  Note(start=92.543182, end=92.706818, pitch=78, velocity=45),
#  Note(start=92.613636, end=92.729545, pitch=64, velocity=66),
#  Note(start=92.438636, end=92.752273, pitch=59, velocity=52),
#  Note(start=92.729545, end=92.834091, pitch=64, velocity=66),
#  Note(start=92.393182, end=92.856818, pitch=83, velocity=81),
#  Note(start=92.834091, end=92.938636, pitch=64, velocity=68),
#  Note(start=92.834091, end=93.043182, pitch=67, velocity=38),
#  Note(start=92.938636, end=93.147727, pitch=64, velocity=55),
#  Note(start=93.043182, end=93.181818, pitch=67, velocity=49),
#  Note(start=92.834091, end=93.218182, pitch=48, velocity=50),
#  ...]

# %%
similarityPitchedDual(midi, pm_data, n_shingle, round_place, False)
# Out:
# 0.28198025427942325

# %%
def dim(a):
    if not type(a) == list:
        return []
    if (len(a) == 0):
        return [1]
    return [len(a)] + dim(a[0])

# Returns the intersection of two lists
def intersection(A, B):
    interSet = []
    for a in A:
        if a in B and not a in interSet:
            interSet.append(a)
    return interSet

# Returns the union of two lists
def union(A, B):
    unionSet = []
    for a in A:
        unionSet.append(a)
    for b in B:
        if not (b in unionSet):
            unionSet.append(b)
    return unionSet

# %%
# Returns a list of pitch-separated start times for Mido input
def startTimesPitchedMido(midi, round_place, octave_ignored):
    number_notes = 128
    if (octave_ignored):
        number_notes = 12
    first_note_start_time = -1.0
    note_startTimes = [None] * number_notes
    for i in range(0, number_notes):
        note_startTimes[i] = []
    currentTime = 0.0
    triggered = False
    # Grab list of notes sorted by pitch (either octave-agnostic or dependent)
    for i in midi:
        triggered = True
        if i.type == 'note_on' or i.type == 'note_off':
            if (octave_ignored):
                note_startTimes[i.note % 12].append(currentTime + i.time)
            else:
                note_startTimes[i.note].append(currentTime + i.time)
            if (first_note_start_time == -1.0): first_note_start_time = i.time
            currentTime += i.time
    # Adjust start time to be 0
    if triggered:
        for i in range(0, len(note_startTimes)):
            for j in range(0, len(note_startTimes[i])):
                note_startTimes[i][j] -= first_note_start_time
                note_startTimes[i][j] = round(note_startTimes[i][j], round_place)
    # Remove duplicates
    for i in range(0, len(note_startTimes)):
        noDuplicatesList = []
        for j in range(0, len(note_startTimes[i])):
            if not note_startTimes[i][j] in noDuplicatesList:
                noDuplicatesList.append(note_startTimes[i][j])
        note_startTimes[i] = noDuplicatesList
    return note_startTimes

# Returns a list of pitch-separated start times for PrettyMIDI input
def startTimesPitchedPretty(midi, round_place, octave_ignored):
    number_notes = 128
    if (octave_ignored):
        number_notes = 12
    first_note_start_time = -1.0
    note_startTimes = [None] * number_notes
    for i in range(0, number_notes):
        note_startTimes[i] = []
    triggered = False
    # Grab list of notes sorted by pitch (either octave-agnostic or dependent)
    for note in midi.instruments[0].notes:
        triggered = True
        if (octave_ignored):
            note_startTimes[note.pitch % 12].append(note.start)
        else:
            note_startTimes[note.pitch].append(note.start)
        if (first_note_start_time == -1.0): first_note_start_time = note.start
    # Adjust start time to be 0
    if triggered:
        for i in range(0, len(note_startTimes)):
            for j in range(0, len(note_startTimes[i])):
                note_startTimes[i][j] -= midi.instruments[0].notes[0].start
                note_startTimes[i][j] = round(note_startTimes[i][j], round_place)
    # Remove duplicates
    for i in range(0, len(note_startTimes)):
        noDuplicatesList = []
        for j in range(0, len(note_startTimes[i])):
            if not note_startTimes[i][j] in noDuplicatesList:
                noDuplicatesList.append(note_startTimes[i][j])
        note_startTimes[i] = noDuplicatesList
    return note_startTimes

# Returns a list of shingles of elements in a 1D list
def nShingle(myList, n):
    if n > len(myList): return []
    if n == len(myList): return [myList]
    shingleList = []
    for i in range(0, len(myList) - n + 1):
        shingle = []
        for j in range(i, i + n):
            shingle.append(myList[j])
        shingleList.append(shingle)
    return shingleList

# Returns a list of shingles of a 2D list
def nShinglePitched(my2Dlist, n):
    fullList = [None] * len(my2Dlist)
    for i in range(0, len(my2Dlist)):
        fullList[i] = nShingle(my2Dlist[i], n)
    return fullList

# Returns a pitch-adjusted similarity coefficient of two MIDI files
def similarityPitchedDual(midiMido, midiPretty, n_shingle, round_place, octave_ignored):
    startTimesPitched1 = startTimesPitchedMido(midiMido, round_place, octave_ignored)
    startTimesPitched2 = startTimesPitchedPretty(midiPretty, round_place, octave_ignored)
    shinglesPitched1 = nShinglePitched(startTimesPitched1, n_shingle)
    shinglesPitched2 = nShinglePitched(startTimesPitched2, n_shingle)
    weighted_sum = 0.0
    total_shingles = 0.0
    for i in range(0, len(startTimesPitched1)):
        sim_denominator = (float)(len(union(shinglesPitched1[i], shinglesPitched2[i])))
        if not sim_denominator == 0:
            sim_numerator = (float)(len(intersection(shinglesPitched1[i], shinglesPitched2[i])))
            similarity = sim_numerator / sim_denominator
            shingles_added = (len(shinglesPitched1[i]) + len(shinglesPitched2[i]))
            weighted_sum += similarity * shingles_added
            total_shingles += shingles_added
    score = weighted_sum / total_shingles * 100
    return score
